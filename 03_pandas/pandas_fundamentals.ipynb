# %% [markdown]
# # Pandas Exercises

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Task 1
#
# Given:
# ```python
# data = {
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi"],
#     "age": [25, 30, 28, 22, 35],
#     "salary": [2500, 3200, 2800, 2100, 4000],
#     "department": ["IT", "HR", "IT", "Marketing", "IT"]
# }
# ```
#
# Write code that displays:
# - The number of rows and columns.
# - The column names.
# - The DataFrame index.
# - The data type of each column.
# - The first 3 lines.
# - The last 2 lines.
# - Get basic statistics

# %%
data = {
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi"],
    "age": [25, 30, 28, 22, 35],
    "salary": [2500, 3200, 2800, 2100, 4000],
    "department": ["IT", "HR", "IT", "Marketing", "IT"]
}

df = pd.DataFrame(data)

print(f"Number of rows and columns: {df.shape}")
print(f"The column names: {df.columns}")
print(f"The DataFrame index: {df.index}")
print(f"The data type of each column:\n{df.dtypes}")
print(f"The first 3 lines:\n{df.head(3)}")
print(f"The last 2 lines:\n{df.tail(2)}")
print(df.describe())

# %% [markdown]
# ## Task 2 - Series from DataFrame
#
# Given:
# ```python
# data = {
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi"],
#     "age": [25, 30, 28, 22, 35],
#     "salary": [2500, 3200, 2800, 2100, 4000],
#     "department": ["IT", "HR", "IT", "Marketing", "IT"]
# }
# ```
#
# Create two variables:
# - ages = ...
# - employee_data = ...
#
# where:
# - ages contains only the age column;
# - employee_data contains the name and salary columns.
#
# Then, check the type of each variable.

# %%
data = {
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi"],
    "age": [25, 30, 28, 22, 35],
    "salary": [2500, 3200, 2800, 2100, 4000],
    "department": ["IT", "HR", "IT", "Marketing", "IT"]
}

df = pd.DataFrame(data)

ages = df["age"]
employee_data = df[["age", "salary"]]

print(ages.dtypes)
print(employee_data.dtypes)

# %% [markdown]
# ### Task 3 - DataFrame from Scratch
#
# Create a DataFrame from scratch containing at least 5 books, for example:
# - title
# - author
# - year
# - price
#
# Then:
# - Display the first 3 books.
# - Display the last 2.
# - Display the column names.
# - Display the dimensions of the DataFrame.
# - Display the column data types.
# - Display statistics for the numerical columns.

# %%
books = {
    "title": ["The Hobbit", "1984", "Dune", "The Name of the Wind", "The Martian"],
    "author": ["J.R.R. Tolkien", "George Orwell", "Frank Herbert", "Patrick Rothfuss", "Andy Weir"],
    "year": [1937, 1949, 1965, 2007, 2011],
    "price": [14.99, 12.50, 18.99, 16.75, 13.49]
}

books_df = pd.DataFrame(books)

print(f"First 3 books:\n{books_df.head(3)}")
print(f"Last 2 books:\n{books_df.tail(2)}")
print(f"Column names: {books_df.columns}")
print(f"DataFrame dimensions: {books_df.shape}")
print(f"Column data types:\n{books_df.dtypes}")
print(f"Display statistics for the numerical columns:\n{books_df.describe()}")

# %%
df_indexed = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
},
index=["EMP101", "EMP205", "EMP309", "EMP412", "EMP550", "EMP623", "EMP741"]
)

# %% [markdown]
# ## Task 4
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
#
# Use loc to display the first row.

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df.loc[0]

# %% [markdown]
# ## Task 5
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
#
# Use loc to display the third row.

# %% [markdown]
# ## Task 6
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
# Display only the name of the person with index 3.
#
# Expected result:
# - Anna

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df.loc[3, "name"]

# %% [markdown]
# ## Task 7
#
# Display the name and salary of the person with index 4.
#
# Expected:
# - Georgi    4000

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df.loc[4, ["name", "salary"]]

# %% [markdown]
# ## Task 8
#
# Display the rows with indices:
#
# ```text
# 0
# 2
# 5
# ```

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df.loc[[0, 2, 5]]

# %% [markdown]
# ## Task 9
#
# Display only the following columns for rows 1, 3, and 6:
# - name
# - department

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df.loc[[1, 3, 6], ["name", "department"]]

# %% [markdown]
# ## Task 10
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
#
# Use `iloc` to display the first row.

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df.iloc[0]

# %% [markdown]
# ## Task 11
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
#
# Display the value 2800 using only `iloc`.

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df.iloc[2, 2]

# %% [markdown]
# ## Task 12
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
# Using `iloc` to display for Peter:
# - name
# - salary

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df.iloc[2, [0, 2]]

# %% [markdown]
# ## Task 13
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
#
# Using `iloc`, display the first 3 and last 3 rows.

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

print(df.iloc[:3])
print(df.iloc[-3:])

# %% [markdown]
# ## Task 14
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
#
#
# Using `iloc`, display all rows, but only:
# - name
# - salary

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df.iloc[:, [0, 2]]

# %% [markdown]
# ## Task 15
#
# Given:
#
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
#
# Using `iloc`, display for the first 4 rows:
# - name
# - age
# - salary

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df.iloc[: 4, :3]

# %% [markdown]
# ## Task 16
#
# Given:
# ```python
# df_indexed = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# },
# index=["EMP101", "EMP205", "EMP309", "EMP412", "EMP550", "EMP623", "EMP741"]
# )
# ```
#
# Use `loc` and `iloc` to display Peter.

# %%
df_indexed = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
},
index=["EMP101", "EMP205", "EMP309", "EMP412", "EMP550", "EMP623", "EMP741"]
)

print(df_indexed.loc["EMP309"])
print(df_indexed.iloc[2])

# %% [markdown]
# ## Task 17
#
# Given:
# ```python
# df_indexed = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# },
# index=["EMP101", "EMP205", "EMP309", "EMP412", "EMP550", "EMP623", "EMP741"]
# )
# ```
#
# Use `loc` and `iloc` to display Georgi's salary.

# %%
df_indexed = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
},
index=["EMP101", "EMP205", "EMP309", "EMP412", "EMP550", "EMP623", "EMP741"]
)

df_indexed.loc["EMP550", "salary"]
df_indexed.iloc[4, 2]

# %% [markdown]
# ## Task 18
#
# Given:
# ```python
# df_indexed = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# },
# index=["EMP101", "EMP205", "EMP309", "EMP412", "EMP550", "EMP623", "EMP741"]
# )
# ```
#
# Use `loc` and `iloc` to display:
# ```text
# Maria
# Peter
# Anna
# ```

# %%
df_indexed = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
},
index=["EMP101", "EMP205", "EMP309", "EMP412", "EMP550", "EMP623", "EMP741"]
)

df_indexed.loc[["EMP205", "EMP309", "EMP412"], "name"]
df.iloc[[1, 2, 3], 0]

# %% [markdown]
# ## Task 19
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
#
# Use:
#
# `df.loc[1:5]` and `df.iloc[1:5]`
#
# and describe which indices you get.

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

print(f"df.loc[1:5]:\n{df.loc[1:5]}\n")
print(f"df.iloc[1:5]\n{df.iloc[1:5]}")

# %% [markdown]
# ## Task 20
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
#
# Use `loc` and `iloc` to get:
# - Ivan
# - Maria
# - Peter
# - Anna

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

print(f"df.loc:\n{df.loc[:3]}\n")
print(f"df.iloc:\n{df.loc[:4]}")

# %% [markdown]
# ## Task 21
#
# Given:
# ```python
# df_indexed = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# },
# index=["EMP101", "EMP205", "EMP309", "EMP412", "EMP550", "EMP623", "EMP741"]
# )
# ```
#
# For df_indexed, use `loc` and `iloc` to select:
# - EMP205 → EMP550

# %%
df_indexed = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
},
index=["EMP101", "EMP205", "EMP309", "EMP412", "EMP550", "EMP623", "EMP741"]
)

print(f"df_indexed.loc:\n{df_indexed.loc["EMP205": "EMP550"]}")
print(f"df_indexed.iloc:\n{df_indexed.iloc[1:5]}")

# %% [markdown]
# ## Task 22
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
#
# Show all employees who are:
# - age > 25

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df[df["age"] > 25]

# %% [markdown]
# ## Task 23
#
# Given:
#
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
#
# Show all employees who are:
# - salary > 3000

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df[df["salary"] > 3000]

# %% [markdown]
# ## Task 24
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
#
# Show all employees from:
# - IT

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df[df["department"] == "IT"]

# %% [markdown]
# ## Task 25
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
#
# Show all employees who do not work in IT.

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df[df["department"] != "IT"]

# %% [markdown]
# ## Task 26
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
#
# Show the employees who:
# - work in IT AND salary > 2800

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df[(df["department"] == "IT") & (df["salary"] > 2800)]

# %% [markdown]
# ## Task 27
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
#
# Show the employees who:
# - work in HR OR work in Marketing

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df[(df["department"] == "HR") | (df["department"] == "Marketing")]

# %% [markdown]
# ## Task 28
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
#
# Show the employees who:
# - do not work in HR AND salary > 2500

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df[(df["department"] != "HR") & (df["salary"] > 2500)]

# %% [markdown]
# ## Task 29
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
#
# Show only:
# - name
# - salary
# for employees earning over 3000.

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df[df["salary"] > 3000][["name", "salary"]]

# %% [markdown]
# ## Task 30
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
#
# Show only:
# - name
# - department
# for employees working in IT.

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df[df["department"] == "IT"][["name", "department"]]

# %% [markdown]
# ## Task 31
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
# Show only:
# - name
# - salary
# for employees who:
# - work in IT AND salary >= 2800

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df[(df["department"] == "IT") & (df["salary"] >= 2800)][["name", "salary"]]

# %% [markdown]
# ## Task 32
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
#
# Show:
# - name
# - department
# - salary
#
# for employees who meet at least one of the following conditions:
# - age < 25
# OR
# - salary >= 3500
# OR
# - work in IT AND salary > 2500

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df[(df["age"] < 25) | (df["salary"] >= 3500) | ((df["department"] == "IT") & (df["salary"] > 2500))][["name", "department", "salary"]]

# %% [markdown]
# ## Task 33
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
#
# Sort the employees by salary in ascending order.

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df.sort_values(by="salary")

# %% [markdown]
# ## Task 34
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
#
# Sort them by age in descending order.

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df.sort_values(by="age", ascending=False)

# %% [markdown]
# ## Task 35
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
#
# Sort by department in ascending order, and within each department — by salary in descending order.

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df.sort_values(by=["department", "salary"], ascending=[True, False])

# %% [markdown]
# ## Task 36
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
#
# - Create a column `annual_salary` using salary.
# - Create a column `salary_after_raise` where everyone receives a 10% raise.
# - Add a column `bonus` with a value of 500 for everyone.

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df["annual_salary"] = df["salary"] * 12
df["salary_after_raise"] = df["salary"] * 1.1
df["bonus"] = 500
df

# %% [markdown]
# ## Task 37
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
#
# Use `loc` to change Anna's salary to 3000.

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df.loc[3, "salary"] = 3000
df

# %% [markdown]
# ## Task 38
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
#
# Increase the salary of all IT employees by 15%.

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df["salary"] = df["salary"].astype(float)

df.loc[
    df["department"] == "IT",
    "salary"
] *= 1.15

# %% [markdown]
# ## Task 39
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
#
# - Create a Boolean column `is_senior` which is True if age >= 30, otherwise False.
# - Remove the `is_senior` column.
# - Rename:
# name → employee_name
# salary → monthly_salary

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df["it_senior"] = False
df.loc[
    df["age"] >= 30,
    "it_senior"
] = True

df = df.drop("it_senior", axis = 1)

df = df.rename(
    columns={
        "name": "employee_name",
        "salary": "monthly_salary"
    }
)

df

# %% [markdown]
# ## Task 40
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
#
# - Display all unique departments.
# - How many different departments are there?
# - How many employees are there in each department?

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

print(df["department"].unique())
print(df["department"].nunique())
print(df["department"].value_counts())

# %% [markdown]
# ## Task 41
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
#     "age": [25, 30, 28, 22, 35, 27, 31],
#     "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing"
#     ]
# })
# ```
# - Calculate the percentage of employees working in IT.
# - Calculate the percentage working in HR.

# %%
df = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena", "Nikolay"],
    "age": [25, 30, 28, 22, 35, 27, 31],
    "salary": [2500, 3200, 2800, 2100, 4000, 2900, 3500],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing"
    ]
})

df["department"].value_counts(normalize=True) * 100

# %% [markdown]
# ## Task 42
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": [
#         "Ivan", "Maria", "Peter", "Anna", "Georgi",
#         "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
#     ],
#     "department": [
#         "IT", "HR", "IT", "Marketing", "IT",
#         "HR", "Marketing", "IT", "HR", "Marketing"
#     ],
#     "age": [
#         25, 30, 28, 22, 35,
#         27, 31, 29, 34, 26
#     ],
#     "salary": [
#         2500, 3200, 2800, 2100, 4000,
#         2900, 3500, 3100, 3700, 2600
#     ],
#     "years_experience": [
#         2, 6, 4, 1, 10,
#         4, 7, 5, 9, 3
#     ]
# })
# ```
#
# - How many employees are there in each department?
# - Find the average salary for each department.
# - Find the maximum salary in each department.
# - Find the total sum of salaries for each department.
# - Find the average age in each department.

# %%
df = pd.DataFrame({
    "name": [
        "Ivan", "Maria", "Peter", "Anna", "Georgi",
        "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
    ],
    "department": [
        "IT", "HR", "IT", "Marketing", "IT",
        "HR", "Marketing", "IT", "HR", "Marketing"
    ],
    "age": [
        25, 30, 28, 22, 35,
        27, 31, 29, 34, 26
    ],
    "salary": [
        2500, 3200, 2800, 2100, 4000,
        2900, 3500, 3100, 3700, 2600
    ],
    "years_experience": [
        2, 6, 4, 1, 10,
        4, 7, 5, 9, 3
    ]
})

df.groupby("department").count()
df.groupby("department")["salary"].mean()
df.groupby("department")["salary"].max()
df.groupby("department")["salary"].sum()
df.groupby("department")["age"].mean()

# %% [markdown]
# ## Task 42
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": [
#         "Ivan", "Maria", "Peter", "Anna", "Georgi",
#         "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
#     ],
#     "department": [
#         "IT", "HR", "IT", "Marketing", "IT",
#         "HR", "Marketing", "IT", "HR", "Marketing"
#     ],
#     "age": [
#         25, 30, 28, 22, 35,
#         27, 31, 29, 34, 26
#     ],
#     "salary": [
#         2500, 3200, 2800, 2100, 4000,
#         2900, 3500, 3100, 3700, 2600
#     ],
#     "years_experience": [
#         2, 6, 4, 1, 10,
#         4, 7, 5, 9, 3
#     ]
# })
# ```
#
# Which department has the highest average salary?

# %%
df = pd.DataFrame({
    "name": [
        "Ivan", "Maria", "Peter", "Anna", "Georgi",
        "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
    ],
    "department": [
        "IT", "HR", "IT", "Marketing", "IT",
        "HR", "Marketing", "IT", "HR", "Marketing"
    ],
    "age": [
        25, 30, 28, 22, 35,
        27, 31, 29, 34, 26
    ],
    "salary": [
        2500, 3200, 2800, 2100, 4000,
        2900, 3500, 3100, 3700, 2600
    ],
    "years_experience": [
        2, 6, 4, 1, 10,
        4, 7, 5, 9, 3
    ]
})

df.groupby("department")["salary"].mean().idxmax()

# %% [markdown]
# ## Task 42
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": [
#         "Ivan", "Maria", "Peter", "Anna", "Georgi",
#         "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
#     ],
#     "department": [
#         "IT", "HR", "IT", "Marketing", "IT",
#         "HR", "Marketing", "IT", "HR", "Marketing"
#     ],
#     "age": [
#         25, 30, 28, 22, 35,
#         27, 31, 29, 34, 26
#     ],
#     "salary": [
#         2500, 3200, 2800, 2100, 4000,
#         2900, 3500, 3100, 3700, 2600
#     ],
#     "years_experience": [
#         2, 6, 4, 1, 10,
#         4, 7, 5, 9, 3
#     ]
# })
# ```
#
# Which department has the lowest average age?

# %%
df = pd.DataFrame({
    "name": [
        "Ivan", "Maria", "Peter", "Anna", "Georgi",
        "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
    ],
    "department": [
        "IT", "HR", "IT", "Marketing", "IT",
        "HR", "Marketing", "IT", "HR", "Marketing"
    ],
    "age": [
        25, 30, 28, 22, 35,
        27, 31, 29, 34, 26
    ],
    "salary": [
        2500, 3200, 2800, 2100, 4000,
        2900, 3500, 3100, 3700, 2600
    ],
    "years_experience": [
        2, 6, 4, 1, 10,
        4, 7, 5, 9, 3
    ]
})

df.groupby("department")["age"].mean().idxmin()

# %% [markdown]
# ## Task 43
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": [
#         "Ivan", "Maria", "Peter", "Anna", "Georgi",
#         "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
#     ],
#     "department": [
#         "IT", "HR", "IT", "Marketing", "IT",
#         "HR", "Marketing", "IT", "HR", "Marketing"
#     ],
#     "age": [
#         25, 30, 28, 22, 35,
#         27, 31, 29, 34, 26
#     ],
#     "salary": [
#         2500, 3200, 2800, 2100, 4000,
#         2900, 3500, 3100, 3700, 2600
#     ],
#     "years_experience": [
#         2, 6, 4, 1, 10,
#         4, 7, 5, 9, 3
#     ]
# })
# ```
#
# Who is the highest-paid employee in each department?

# %%
df = pd.DataFrame({
    "name": [
        "Ivan", "Maria", "Peter", "Anna", "Georgi",
        "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
    ],
    "department": [
        "IT", "HR", "IT", "Marketing", "IT",
        "HR", "Marketing", "IT", "HR", "Marketing"
    ],
    "age": [
        25, 30, 28, 22, 35,
        27, 31, 29, 34, 26
    ],
    "salary": [
        2500, 3200, 2800, 2100, 4000,
        2900, 3500, 3100, 3700, 2600
    ],
    "years_experience": [
        2, 6, 4, 1, 10,
        4, 7, 5, 9, 3
    ]
})

df.loc[df.groupby("department")["salary"].idxmax(), ["department", "name", "salary"]]

# %% [markdown]
# ## Task 44
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": [
#         "Ivan", "Maria", "Peter", "Anna", "Georgi",
#         "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
#     ],
#     "department": [
#         "IT", "HR", "IT", "Marketing", "IT",
#         "HR", "Marketing", "IT", "HR", "Marketing"
#     ],
#     "age": [
#         25, 30, 28, 22, 35,
#         27, 31, 29, 34, 26
#     ],
#     "salary": [
#         2500, 3200, 2800, 2100, 4000,
#         2900, 3500, 3100, 3700, 2600
#     ],
#     "years_experience": [
#         2, 6, 4, 1, 10,
#         4, 7, 5, 9, 3
#     ]
# })
# ```
#
# For each department, find:
#
# average salary
# minimum salary
# maximum salary
#
# Use a single groupby() rather than three separate operations.

# %%
df = pd.DataFrame({
    "name": [
        "Ivan", "Maria", "Peter", "Anna", "Georgi",
        "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
    ],
    "department": [
        "IT", "HR", "IT", "Marketing", "IT",
        "HR", "Marketing", "IT", "HR", "Marketing"
    ],
    "age": [
        25, 30, 28, 22, 35,
        27, 31, 29, 34, 26
    ],
    "salary": [
        2500, 3200, 2800, 2100, 4000,
        2900, 3500, 3100, 3700, 2600
    ],
    "years_experience": [
        2, 6, 4, 1, 10,
        4, 7, 5, 9, 3
    ]
})

df.groupby("department").agg(
    average_salary = ("salary", "mean"),
    minimum_salary = ("salary", "min"),
    maximum_salary = ("salary", "max")
)

# %% [markdown]
# ## Task 45
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": [
#         "Ivan", "Maria", "Peter", "Anna", "Georgi",
#         "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
#     ],
#     "department": [
#         "IT", "HR", "IT", "Marketing", "IT",
#         "HR", "Marketing", "IT", "HR", "Marketing"
#     ],
#     "age": [
#         25, 30, 28, 22, 35,
#         27, 31, 29, 34, 26
#     ],
#     "salary": [
#         2500, 3200, 2800, 2100, 4000,
#         2900, 3500, 3100, 3700, 2600
#     ],
#     "years_experience": [
#         2, 6, 4, 1, 10,
#         4, 7, 5, 9, 3
#     ]
# })
# ```
#
# Create a table with the following columns:
# - department
# - average_salary
# - minimum_salary
# - maximum_salary
# - average_age

# %%
df = pd.DataFrame({
    "name": [
        "Ivan", "Maria", "Peter", "Anna", "Georgi",
        "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
    ],
    "department": [
        "IT", "HR", "IT", "Marketing", "IT",
        "HR", "Marketing", "IT", "HR", "Marketing"
    ],
    "age": [
        25, 30, 28, 22, 35,
        27, 31, 29, 34, 26
    ],
    "salary": [
        2500, 3200, 2800, 2100, 4000,
        2900, 3500, 3100, 3700, 2600
    ],
    "years_experience": [
        2, 6, 4, 1, 10,
        4, 7, 5, 9, 3
    ]
})


df.groupby("department").agg(
    average_salary = ("salary", "mean"),
    minimum_salary = ("salary", "min"),
    maximum_salary = ("salary", "max"),
    average_age = ("age", "mean")
)

# %% [markdown]
# ## Task 46
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": [
#         "Ivan", "Maria", "Peter", "Anna", "Georgi",
#         "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
#     ],
#     "department": [
#         "IT", "HR", "IT", "Marketing", "IT",
#         "HR", "Marketing", "IT", "HR", "Marketing"
#     ],
#     "age": [
#         25, 30, 28, 22, 35,
#         27, 31, 29, 34, 26
#     ],
#     "salary": [
#         2500, 3200, 2800, 2100, 4000,
#         2900, 3500, 3100, 3700, 2600
#     ],
#     "years_experience": [
#         2, 6, 4, 1, 10,
#         4, 7, 5, 9, 3
#     ]
# })
# ```
#
# For each department, find:
# - the number of employees
# - the average years_experience
# - the maximum years_experience

# %%
df = pd.DataFrame({
    "name": [
        "Ivan", "Maria", "Peter", "Anna", "Georgi",
        "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
    ],
    "department": [
        "IT", "HR", "IT", "Marketing", "IT",
        "HR", "Marketing", "IT", "HR", "Marketing"
    ],
    "age": [
        25, 30, 28, 22, 35,
        27, 31, 29, 34, 26
    ],
    "salary": [
        2500, 3200, 2800, 2100, 4000,
        2900, 3500, 3100, 3700, 2600
    ],
    "years_experience": [
        2, 6, 4, 1, 10,
        4, 7, 5, 9, 3
    ]
})

df.groupby("department").agg(
    employee_count = ("name", "count"),
    avg_years_experience = ("years_experience", "mean"),
    max_years_experience = ("years_experience", "max")
)

# %% [markdown]
# ## Task 47
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": [
#         "Ivan", "Maria", "Peter", "Anna", "Georgi",
#         "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
#     ],
#     "department": [
#         "IT", "HR", "IT", "Marketing", "IT",
#         "HR", "Marketing", "IT", "HR", "Marketing"
#     ],
#     "age": [
#         25, 30, 28, 22, 35,
#         27, 31, 29, 34, 26
#     ],
#     "salary": [
#         2500, 3200, 2800, 2100, 4000,
#         2900, 3500, 3100, 3700, 2600
#     ],
#     "years_experience": [
#         2, 6, 4, 1, 10,
#         4, 7, 5, 9, 3
#     ]
# })
# ```
#
# Group the employees by:
# - department
# - age
#
# and count how many employees there are in each combination.

# %%
df = pd.DataFrame({
    "name": [
        "Ivan", "Maria", "Peter", "Anna", "Georgi",
        "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
    ],
    "department": [
        "IT", "HR", "IT", "Marketing", "IT",
        "HR", "Marketing", "IT", "HR", "Marketing"
    ],
    "age": [
        25, 30, 28, 22, 35,
        27, 31, 29, 34, 26
    ],
    "salary": [
        2500, 3200, 2800, 2100, 4000,
        2900, 3500, 3100, 3700, 2600
    ],
    "years_experience": [
        2, 6, 4, 1, 10,
        4, 7, 5, 9, 3
    ]
})

df.groupby(["department", "age"]).count()

# %% [markdown]
# ## Task 48
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": [
#         "Ivan", "Maria", "Peter", "Anna", "Georgi",
#         "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
#     ],
#     "department": [
#         "IT", "HR", "IT", "Marketing", "IT",
#         "HR", "Marketing", "IT", "HR", "Marketing"
#     ],
#     "age": [
#         25, 30, 28, 22, 35,
#         27, 31, 29, 34, 26
#     ],
#     "salary": [
#         2500, 3200, 2800, 2100, 4000,
#         2900, 3500, 3100, 3700, 2600
#     ],
#     "years_experience": [
#         2, 6, 4, 1, 10,
#         4, 7, 5, 9, 3
#     ]
# })
# ```
#
# Group by:
# - department
# - years_experience
#
# and find the average salary for each combination.

# %%
df = pd.DataFrame({
    "name": [
        "Ivan", "Maria", "Peter", "Anna", "Georgi",
        "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
    ],
    "department": [
        "IT", "HR", "IT", "Marketing", "IT",
        "HR", "Marketing", "IT", "HR", "Marketing"
    ],
    "age": [
        25, 30, 28, 22, 35,
        27, 31, 29, 34, 26
    ],
    "salary": [
        2500, 3200, 2800, 2100, 4000,
        2900, 3500, 3100, 3700, 2600
    ],
    "years_experience": [
        2, 6, 4, 1, 10,
        4, 7, 5, 9, 3
    ]
})

df.groupby(["department", "years_experience"])["salary"].mean()

# %% [markdown]
# ## Task 49
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": [
#         "Ivan", "Maria", "Peter", "Anna", "Georgi",
#         "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
#     ],
#     "department": [
#         "IT", "HR", "IT", "Marketing", "IT",
#         "HR", "Marketing", "IT", "HR", "Marketing"
#     ],
#     "age": [
#         25, 30, 28, 22, 35,
#         27, 31, 29, 34, 26
#     ],
#     "salary": [
#         2500, 3200, 2800, 2100, 4000,
#         2900, 3500, 3100, 3700, 2600
#     ],
#     "years_experience": [
#         2, 6, 4, 1, 10,
#         4, 7, 5, 9, 3
#     ]
# })
# ```
#
# Which department has the most employees with more than 5 years of experience?

# %%
df = pd.DataFrame({
    "name": [
        "Ivan", "Maria", "Peter", "Anna", "Georgi",
        "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
    ],
    "department": [
        "IT", "HR", "IT", "Marketing", "IT",
        "HR", "Marketing", "IT", "HR", "Marketing"
    ],
    "age": [
        25, 30, 28, 22, 35,
        27, 31, 29, 34, 26
    ],
    "salary": [
        2500, 3200, 2800, 2100, 4000,
        2900, 3500, 3100, 3700, 2600
    ],
    "years_experience": [
        2, 6, 4, 1, 10,
        4, 7, 5, 9, 3
    ]
})

df[df["years_experience"] > 5].groupby("department").size().idxmax()

# %% [markdown]
# ## Task 50
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": [
#         "Ivan", "Maria", "Peter", "Anna", "Georgi",
#         "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
#     ],
#     "department": [
#         "IT", "HR", "IT", "Marketing", "IT",
#         "HR", "Marketing", "IT", "HR", "Marketing"
#     ],
#     "age": [
#         25, 30, 28, 22, 35,
#         27, 31, 29, 34, 26
#     ],
#     "salary": [
#         2500, 3200, 2800, 2100, 4000,
#         2900, 3500, 3100, 3700, 2600
#     ],
#     "years_experience": [
#         2, 6, 4, 1, 10,
#         4, 7, 5, 9, 3
#     ]
# })
# ```
#
# Find the average department salary only for employees who are 30 or above.

# %%
df = pd.DataFrame({
    "name": [
        "Ivan", "Maria", "Peter", "Anna", "Georgi",
        "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
    ],
    "department": [
        "IT", "HR", "IT", "Marketing", "IT",
        "HR", "Marketing", "IT", "HR", "Marketing"
    ],
    "age": [
        25, 30, 28, 22, 35,
        27, 31, 29, 34, 26
    ],
    "salary": [
        2500, 3200, 2800, 2100, 4000,
        2900, 3500, 3100, 3700, 2600
    ],
    "years_experience": [
        2, 6, 4, 1, 10,
        4, 7, 5, 9, 3
    ]
})

# %%
df[df["age"] >= 30].groupby("department")["salary"].mean()

# %% [markdown]
# ## Task 51
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": [
#         "Ivan", "Maria", "Peter", "Anna", "Georgi",
#         "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
#     ],
#     "department": [
#         "IT", "HR", "IT", "Marketing", "IT",
#         "HR", "Marketing", "IT", "HR", "Marketing"
#     ],
#     "age": [
#         25, 30, 28, 22, 35,
#         27, 31, 29, 34, 26
#     ],
#     "salary": [
#         2500, 3200, 2800, 2100, 4000,
#         2900, 3500, 3100, 3700, 2600
#     ],
#     "years_experience": [
#         2, 6, 4, 1, 10,
#         4, 7, 5, 9, 3
#     ]
# })
# ```
#
# Find the average department salary of employees with years_experience >= 5

# %%
df = pd.DataFrame({
    "name": [
        "Ivan", "Maria", "Peter", "Anna", "Georgi",
        "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
    ],
    "department": [
        "IT", "HR", "IT", "Marketing", "IT",
        "HR", "Marketing", "IT", "HR", "Marketing"
    ],
    "age": [
        25, 30, 28, 22, 35,
        27, 31, 29, 34, 26
    ],
    "salary": [
        2500, 3200, 2800, 2100, 4000,
        2900, 3500, 3100, 3700, 2600
    ],
    "years_experience": [
        2, 6, 4, 1, 10,
        4, 7, 5, 9, 3
    ]
})

df[df["years_experience"] >= 5].groupby("department")["salary"].mean()

# %% [markdown]
# ## Task 52
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": [
#         "Ivan", "Maria", "Peter", "Anna", "Georgi",
#         "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
#     ],
#     "department": [
#         "IT", "HR", "IT", "Marketing", "IT",
#         "HR", "Marketing", "IT", "HR", "Marketing"
#     ],
#     "age": [
#         25, 30, 28, 22, 35,
#         27, 31, 29, 34, 26
#     ],
#     "salary": [
#         2500, 3200, 2800, 2100, 4000,
#         2900, 3500, 3100, 3700, 2600
#     ],
#     "years_experience": [
#         2, 6, 4, 1, 10,
#         4, 7, 5, 9, 3
#     ]
# })
# ```
#
# Create a DataFrame containing the following for each department:
# - employee_count
# - average_salary
# - minimum_salary
# - maximum_salary
# - total_salary
# - average_experience
#
# Then:
# - Sort the result by average_salary in descending order.
# - Find the department with the highest average salary.
# - Find the department with the highest total salary.

# %%
df = pd.DataFrame({
    "name": [
        "Ivan", "Maria", "Peter", "Anna", "Georgi",
        "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
    ],
    "department": [
        "IT", "HR", "IT", "Marketing", "IT",
        "HR", "Marketing", "IT", "HR", "Marketing"
    ],
    "age": [
        25, 30, 28, 22, 35,
        27, 31, 29, 34, 26
    ],
    "salary": [
        2500, 3200, 2800, 2100, 4000,
        2900, 3500, 3100, 3700, 2600
    ],
    "years_experience": [
        2, 6, 4, 1, 10,
        4, 7, 5, 9, 3
    ]
})

new_df = df.groupby("department").agg(
    employee_count = ("name", "count"),
    average_salary = ("salary", "mean"),
    minimum_salary = ("salary", "min"),
    maximum_salary = ("salary", "max"),
    total_salary = ("salary", "sum"),
    average_experience = ("years_experience", "mean")
)

new_df.sort_values("average_salary", ascending=False, inplace=True)
new_df["average_salary"].idxmax()
new_df["total_salary"].idxmax()

# %% [markdown]
# ## Task 53
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": [
#         "Ivan", "Maria", "Peter", "Anna", "Georgi",
#         "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
#     ],
#     "age": [
#         25, 30, np.nan, 22, 35,
#         27, 31, np.nan, 34, 26
#     ],
#     "salary": [
#         2500, np.nan, 2800, 2100, 4000,
#         np.nan, 3500, 3100, np.nan, 2600
#     ],
#     "department": [
#         "IT", "HR", "IT", np.nan, "IT",
#         "HR", "Marketing", "IT", np.nan, "Marketing"
#     ]
# })
# ```
#
# - Display a Boolean DataFrame showing the locations of missing values.
# - Display the number of missing values ​​in each column.
# - Find the total number of missing values ​​in the entire DataFrame.
# - Calculate the percentage of missing values ​​for each column.
# - Display only the employees for whom the salary is missing.
# - Display only the employees for whom the department is not missing.

# %%
df = pd.DataFrame({
    "name": [
        "Ivan", "Maria", "Peter", "Anna", "Georgi",
        "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
    ],
    "age": [
        25, 30, np.nan, 22, 35,
        27, 31, np.nan, 34, 26
    ],
    "salary": [
        2500, np.nan, 2800, 2100, 4000,
        np.nan, 3500, 3100, np.nan, 2600
    ],
    "department": [
        "IT", "HR", "IT", np.nan, "IT",
        "HR", "Marketing", "IT", np.nan, "Marketing"
    ]
})

df.isna()
df.isna().sum()
df.isna().sum().sum()
df.isna().mean() * 100 # type: ignore
df.loc[df["salary"].isna()]
df.loc[df["department"].notna()]

# %% [markdown]
# ## Task 54
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": [
#         "Ivan", "Maria", "Peter", "Anna", "Georgi",
#         "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
#     ],
#     "age": [
#         25, 30, np.nan, 22, 35,
#         27, 31, np.nan, 34, 26
#     ],
#     "salary": [
#         2500, np.nan, 2800, 2100, 4000,
#         np.nan, 3500, 3100, np.nan, 2600
#     ],
#     "department": [
#         "IT", "HR", "IT", np.nan, "IT",
#         "HR", "Marketing", "IT", np.nan, "Marketing"
#     ]
# })
# ```
#
# - Remove all rows that contain at least one missing value.
# - Remove only the rows where the salary is missing.
# - Replace missing department values ​​with "Unknown"
# - Replace missing salary values ​​with the average salary.
# - Replace missing age values ​​with the median age.
# - Find the most frequent department and use its value to fill in the missing departments.

# %%
df = pd.DataFrame({
    "name": [
        "Ivan", "Maria", "Peter", "Anna", "Georgi",
        "Elena", "Nikolay", "Viktor", "Daniel", "Laura"
    ],
    "age": [
        25, 30, np.nan, 22, 35,
        27, 31, np.nan, 34, 26
    ],
    "salary": [
        2500, np.nan, 2800, 2100, 4000,
        np.nan, 3500, 3100, np.nan, 2600
    ],
    "department": [
        "IT", "HR", "IT", np.nan, "IT",
        "HR", "Marketing", "IT", np.nan, "Marketing"
    ]
})

df.dropna(how="any")
df.dropna(subset="salary")
df["department"].fillna("Unknown")
df["salary"].fillna(df["salary"].mean())
df["age"].fillna(df["age"].median())
df["department"].fillna(df["department"].value_counts().idxmax())

# %% [markdown]
# ## Task 55
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": [
#         " Ivan ",
#         "MARIA",
#         "Peter",
#         " anna ",
#         "Georgi"
#     ],
#     "age": [
#         25,
#         30,
#         28,
#         22,
#         35
#     ],
#     "salary": [
#         "2500",
#         "3200",
#         "2800",
#         "2100",
#         "4000"
#     ],
#     "department": [
#         " IT ",
#         "HR",
#         "it",
#         " Marketing ",
#         "IT"
#     ]
# })
# ```
# Show the data type of each column.

# %%
df = pd.DataFrame({
    "name": [
        " Ivan ",
        "MARIA",
        "Peter",
        " anna ",
        "Georgi"
    ],
    "age": [
        25,
        30,
        28,
        22,
        35
    ],
    "salary": [
        "2500",
        "3200",
        "2800",
        "2100",
        "4000"
    ],
    "department": [
        " IT ",
        "HR",
        "it",
        " Marketing ",
        "IT"
    ]
})

df.dtypes

# %% [markdown]
# ## Task 56
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": [
#         " Ivan ",
#         "MARIA",
#         "Peter",
#         " anna ",
#         "Georgi"
#     ],
#     "age": [
#         25,
#         30,
#         28,
#         22,
#         35
#     ],
#     "salary": [
#         "2500",
#         "3200",
#         "2800",
#         "2100",
#         "4000"
#     ],
#     "department": [
#         " IT ",
#         "HR",
#         "it",
#         " Marketing ",
#         "IT"
#     ]
# })
# ```
#
# - Convert `salary` from a string to a numeric type.
# Then check by using `df.dtypes`
#
# - Calculate the average `salary`.

# %%
df = pd.DataFrame({
    "name": [
        " Ivan ",
        "MARIA",
        "Peter",
        " anna ",
        "Georgi"
    ],
    "age": [
        25,
        30,
        28,
        22,
        35
    ],
    "salary": [
        "2500",
        "3200",
        "2800",
        "2100",
        "4000"
    ],
    "department": [
        " IT ",
        "HR",
        "it",
        " Marketing ",
        "IT"
    ]
})


df["salary"] = df["salary"].astype(float)
print(df.dtypes)
df["salary"].mean()

# %% [markdown]
# ## Task 57
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": [
#         " Ivan ",
#         "MARIA",
#         "Peter",
#         " anna ",
#         "Georgi"
#     ],
#     "age": [
#         25,
#         30,
#         28,
#         22,
#         35
#     ],
#     "salary": [
#         "2500",
#         "3200",
#         "2800",
#         "2100",
#         "4000"
#     ],
#     "department": [
#         " IT ",
#         "HR",
#         "it",
#         " Marketing ",
#         "IT"
#     ]
# })
# ```
#
# - Remove extra spaces from `name`.
# - Convert all `name` values ​​to lowercase.
# - Convert all `department` values ​​to uppercase and remove whitespace.

# %%
df = pd.DataFrame({
    "name": [
        " Ivan ",
        "MARIA",
        "Peter",
        " anna ",
        "Georgi"
    ],
    "age": [
        25,
        30,
        28,
        22,
        35
    ],
    "salary": [
        "2500",
        "3200",
        "2800",
        "2100",
        "4000"
    ],
    "department": [
        " IT ",
        "HR",
        "it",
        " Marketing ",
        "IT"
    ]
})

df["name"].str.strip().str.lower()
df["department"].str.strip().str.upper()

# %% [markdown]
# ## Task 58
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": [
#         " Ivan ",
#         "MARIA",
#         "Peter",
#         " anna ",
#         "Georgi"
#     ],
#     "age": [
#         25,
#         30,
#         28,
#         22,
#         35
#     ],
#     "salary": [
#         "2500",
#         "3200",
#         "2800",
#         "2100",
#         "4000"
#     ],
#     "department": [
#         " IT ",
#         "HR",
#         "it",
#         " Marketing ",
#         "IT"
#     ]
# })
# ```
#
# Find all employees whose name contains the letter `a`

# %%
df = pd.DataFrame({
    "name": [
        " Ivan ",
        "MARIA",
        "Peter",
        " anna ",
        "Georgi"
    ],
    "age": [
        25,
        30,
        28,
        22,
        35
    ],
    "salary": [
        "2500",
        "3200",
        "2800",
        "2100",
        "4000"
    ],
    "department": [
        " IT ",
        "HR",
        "it",
        " Marketing ",
        "IT"
    ]
})

df[df["name"].str.contains("a")]

# %% [markdown]
# df = pd.DataFrame({
#     "name": [
#         " Ivan ",
#         "MARIA",
#         "Peter",
#         " anna ",
#         "Georgi"
#     ],
#     "age": [
#         25,
#         30,
#         28,
#         22,
#         35
#     ],
#     "salary": [
#         "2500",
#         "3200",
#         "2800",
#         "2100",
#         "4000"
#     ],
#     "department": [
#         " IT ",
#         "HR",
#         "it",
#         " Marketing ",
#         "IT"
#     ]
# })
#
# Find all employees whose name starts with `"A"`

# %%
df = pd.DataFrame({
    "name": [
        " Ivan ",
        "MARIA",
        "Peter",
        " anna ",
        "Georgi"
    ],
    "age": [
        25,
        30,
        28,
        22,
        35
    ],
    "salary": [
        "2500",
        "3200",
        "2800",
        "2100",
        "4000"
    ],
    "department": [
        " IT ",
        "HR",
        "it",
        " Marketing ",
        "IT"
    ]
})

df.loc[df["name"].str.strip().str.slice(0,1) == "A"]

# %% [markdown]
# ## Task 59
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": [
#         " Ivan ",
#         "MARIA",
#         "Peter",
#         " anna ",
#         "Georgi"
#     ],
#     "age": [
#         25,
#         30,
#         28,
#         22,
#         35
#     ],
#     "salary": [
#         "2500",
#         "3200",
#         "2800",
#         "2100",
#         "4000"
#     ],
#     "department": [
#         " IT ",
#         "HR",
#         "it",
#         " Marketing ",
#         "IT"
#     ]
# })
# ```
# Create a new column `name_length` containing the number of characters in the name.

# %%
df = pd.DataFrame({
    "name": [
        " Ivan ",
        "MARIA",
        "Peter",
        " anna ",
        "Georgi"
    ],
    "age": [
        25,
        30,
        28,
        22,
        35
    ],
    "salary": [
        "2500",
        "3200",
        "2800",
        "2100",
        "4000"
    ],
    "department": [
        " IT ",
        "HR",
        "it",
        " Marketing ",
        "IT"
    ]
})

df["name_length"] = df["name"].str.strip().str.len()
df

# %% [markdown]
# ## Task 60
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": [
#         " Ivan ",
#         "MARIA",
#         "Peter",
#         " anna ",
#         "Georgi"
#     ],
#     "age": [
#         25,
#         30,
#         28,
#         22,
#         35
#     ],
#     "salary": [
#         "2500",
#         "3200",
#         "2800",
#         "2100",
#         "4000"
#     ],
#     "department": [
#         " IT ",
#         "HR",
#         "it",
#         " Marketing ",
#         "IT"
#     ]
# })
# ```
#
# Replace in the `department` column:
# - IT → Information Technology
# - HR → Human Resources

# %%
df = pd.DataFrame({
    "name": [
        " Ivan ",
        "MARIA",
        "Peter",
        " anna ",
        "Georgi"
    ],
    "age": [
        25,
        30,
        28,
        22,
        35
    ],
    "salary": [
        "2500",
        "3200",
        "2800",
        "2100",
        "4000"
    ],
    "department": [
        " IT ",
        "HR",
        "it",
        " Marketing ",
        "IT"
    ]
})

df["department"] = df["department"].str.upper().str.replace(
    {"IT": "Information Technology",
     "HR": "Human Resources"}
)

df

# %% [markdown]
# ## Task 61
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": [
#         "  Ivan Petrov ",
#         "Maria Ivanova",
#         "  PETER SMITH",
#         "Anna Brown  ",
#         "georgi dimitrov"
#     ],
#     "salary": [
#         "2500",
#         "3200",
#         "unknown",
#         "2100",
#         "4000"
#     ]
# })
# ```
#
# - Remove whitespace from `name`.
# - Format all names in Title Case.
# - Convert `salary` to numeric.
# - Replace "unknown" with NaN.
# - Identify rows with missing `salary`.
# - Calculate the average `salary` without filling in the NaN values.

# %%
df = pd.DataFrame({
    "name": [
        "  Ivan Petrov ",
        "Maria Ivanova",
        "  PETER SMITH",
        "Anna Brown  ",
        "georgi dimitrov"
    ],
    "salary": [
        "2500",
        "3200",
        "unknown",
        "2100",
        "4000"
    ]
})

df["name"] = df["name"].str.strip().str.title()
df["salary"] = pd.to_numeric(df["salary"], errors="coerce")
df.loc[df["salary"].isna()]
np.nanmean(df["salary"])

# %% [markdown]
# ## Task 62
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": [
#         "Ivan", "Maria", "Peter", "Anna",
#         "Georgi", "Elena", "Nikolay", "Viktor"
#     ],
#     "salary": [
#         2500, 3200, 2800, 2100,
#         4000, 3500, 2700, 4500
#     ],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing", "IT"
#     ],
#     "years_experience": [
#         2, 6, 4, 1,
#         10, 8, 3, 12
#     ]
# })
# ```
#
# Use `map()` and dictionary to transform:
# ```text
# IT → Technology
# HR → Human Resources
# Marketing → Marketing
# ```

# %%
df = pd.DataFrame({
    "name": [
        "Ivan", "Maria", "Peter", "Anna",
        "Georgi", "Elena", "Nikolay", "Viktor"
    ],
    "salary": [
        2500, 3200, 2800, 2100,
        4000, 3500, 2700, 4500
    ],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing", "IT"
    ],
    "years_experience": [
        2, 6, 4, 1,
        10, 8, 3, 12
    ]
})

df["department"] = df["department"].map(
    {
        "IT": "Technology",
        "HR": "Human Resources",
        "Marketing": "Marketing"
    }
)

df

# %% [markdown]
# ## Task 63
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": [
#         "Ivan", "Maria", "Peter", "Anna",
#         "Georgi", "Elena", "Nikolay", "Viktor"
#     ],
#     "salary": [
#         2500, 3200, 2800, 2100,
#         4000, 3500, 2700, 4500
#     ],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing", "IT"
#     ],
#     "years_experience": [
#         2, 6, 4, 1,
#         10, 8, 3, 12
#     ]
# })
# ```
#
# Use `replace()` and dictionary to transform:
# ```text
# IT → Technology
# HR → Human Resources
# Marketing → Marketing
# ```

# %%
df = pd.DataFrame({
    "name": [
        "Ivan", "Maria", "Peter", "Anna",
        "Georgi", "Elena", "Nikolay", "Viktor"
    ],
    "salary": [
        2500, 3200, 2800, 2100,
        4000, 3500, 2700, 4500
    ],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing", "IT"
    ],
    "years_experience": [
        2, 6, 4, 1,
        10, 8, 3, 12
    ]
})

df["department"] = df["department"].replace(
    {
        "IT": "Technology",
        "HR": "Human Resources"
    }
)

df

# %% [markdown]
# ## Task 64
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": [
#         "Ivan", "Maria", "Peter", "Anna",
#         "Georgi", "Elena", "Nikolay", "Viktor"
#     ],
#     "salary": [
#         2500, 3200, 2800, 2100,
#         4000, 3500, 2700, 4500
#     ],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing", "IT"
#     ],
#     "years_experience": [
#         2, 6, 4, 1,
#         10, 8, 3, 12
#     ]
# })
# ```
#
# Use `map()` with lambda to increase all salaries by 10%.

# %%
df = pd.DataFrame({
    "name": [
        "Ivan", "Maria", "Peter", "Anna",
        "Georgi", "Elena", "Nikolay", "Viktor"
    ],
    "salary": [
        2500, 3200, 2800, 2100,
        4000, 3500, 2700, 4500
    ],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing", "IT"
    ],
    "years_experience": [
        2, 6, 4, 1,
        10, 8, 3, 12
    ]
})

df["salary"] = df["salary"].map(lambda x: x * 1.1)

df

# %% [markdown]
# ## Task 65
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": [
#         "Ivan", "Maria", "Peter", "Anna",
#         "Georgi", "Elena", "Nikolay", "Viktor"
#     ],
#     "salary": [
#         2500, 3200, 2800, 2100,
#         4000, 3500, 2700, 4500
#     ],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing", "IT"
#     ],
#     "years_experience": [
#         2, 6, 4, 1,
#         10, 8, 3, 12
#     ]
# })
# ```
#
# Create a column `salary_after_bonus` that contains salary + 15%.

# %%
df = pd.DataFrame({
    "name": [
        "Ivan", "Maria", "Peter", "Anna",
        "Georgi", "Elena", "Nikolay", "Viktor"
    ],
    "salary": [
        2500, 3200, 2800, 2100,
        4000, 3500, 2700, 4500
    ],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing", "IT"
    ],
    "years_experience": [
        2, 6, 4, 1,
        10, 8, 3, 12
    ]
})

df["salary_after_bonus"] = df["salary"] * 1.15
df

# %% [markdown]
# ## Task 66
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": [
#         "Ivan", "Maria", "Peter", "Anna",
#         "Georgi", "Elena", "Nikolay", "Viktor"
#     ],
#     "salary": [
#         2500, 3200, 2800, 2100,
#         4000, 3500, 2700, 4500
#     ],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing", "IT"
#     ],
#     "years_experience": [
#         2, 6, 4, 1,
#         10, 8, 3, 12
#     ]
# })
# ```
#
# Create a function:
#
# ```python
# def salary_category(salary):
# ```
# that returns:
# - salary < 2500 → Low
# - 2500–3499 → Medium
# - salary >= 3500 → High
#
# Then do the same operation using a `lambda` function
# Use `apply()`.

# %%
df = pd.DataFrame({
    "name": [
        "Ivan", "Maria", "Peter", "Anna",
        "Georgi", "Elena", "Nikolay", "Viktor"
    ],
    "salary": [
        2500, 3200, 2800, 2100,
        4000, 3500, 2700, 4500
    ],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing", "IT"
    ],
    "years_experience": [
        2, 6, 4, 1,
        10, 8, 3, 12
    ]
})

def salary_category(salary):
    if salary < 2500:
        return "Low"
    elif salary < 3499:
        return "Medium"
    else:
        return "High"



df["salary_category"] = df["salary"].apply(salary_category)

df["salary_category_lambda"] = df["salary"].apply(
    lambda salary: "Low" if salary < 2500
    else "Medium" if salary < 3500
    else "High"
)

df

# %% [markdown]
# ## Task 67
#
# Given:
# ```python
# df = pd.DataFrame({
#     "name": [
#         "Ivan", "Maria", "Peter", "Anna",
#         "Georgi", "Elena", "Nikolay", "Viktor"
#     ],
#     "salary": [
#         2500, 3200, 2800, 2100,
#         4000, 3500, 2700, 4500
#     ],
#     "department": [
#         "IT", "HR", "IT", "Marketing",
#         "IT", "HR", "Marketing", "IT"
#     ],
#     "years_experience": [
#         2, 6, 4, 1,
#         10, 8, 3, 12
#     ]
# })
# ```
#
# Create column `is_senior` where the employee is Senior only if:
# - salary >= 3000 AND years_experience >= 5
#
# Here use:
# df.apply(..., axis=1)

# %%
df = pd.DataFrame({
    "name": [
        "Ivan", "Maria", "Peter", "Anna",
        "Georgi", "Elena", "Nikolay", "Viktor"
    ],
    "salary": [
        2500, 3200, 2800, 2100,
        4000, 3500, 2700, 4500
    ],
    "department": [
        "IT", "HR", "IT", "Marketing",
        "IT", "HR", "Marketing", "IT"
    ],
    "years_experience": [
        2, 6, 4, 1,
        10, 8, 3, 12
    ]
})

def is_senior(row):
    return (
        row["salary"] >= 3000
        and row["years_experience"] >= 5
    )

df["is_senior"] = df.apply(is_senior, axis=1)

df

# %% [markdown]
# ## Task 68
#
# Given:
# ```python
# employees = pd.DataFrame({
#     "employee_id": [1, 2, 3, 4, 5, 6],
#     "name": [
#         "Ivan", "Maria", "Peter",
#         "Anna", "Georgi", "Elena"
#     ],
#     "department_id": [
#         10, 20, 10, 30, 40, 20
#     ],
#     "salary": [
#         2500, 3200, 2800,
#         2100, 4000, 3500
#     ]
# })
#
# departments = pd.DataFrame({
#     "department_id": [10, 20, 30, 50],
#     "department": [
#         "IT", "HR", "Marketing", "Finance"
#     ],
#     "location": [
#         "Sofia", "Sofia", "Plovdiv", "Varna"
#     ]
# })
# ```
#
# Do a `merge()` between:
# - employees
# - departments
#
# using:
# `on="department_id"`
#
# and see the result.

# %%
employees = pd.DataFrame({
    "employee_id": [1, 2, 3, 4, 5, 6],
    "name": [
        "Ivan", "Maria", "Peter",
        "Anna", "Georgi", "Elena"
    ],
    "department_id": [
        10, 20, 10, 30, 40, 20
    ],
    "salary": [
        2500, 3200, 2800,
        2100, 4000, 3500
    ]
})

departments = pd.DataFrame({
    "department_id": [10, 20, 30, 50],
    "department": [
        "IT", "HR", "Marketing", "Finance"
    ],
    "location": [
        "Sofia", "Sofia", "Plovdiv", "Varna"
    ]
})

result = employees.merge(
    departments,
    on="department_id"
)

result

# %% [markdown]
# ## Task 69
#
# Given:
# ```python
# employees = pd.DataFrame({
#     "employee_id": [1, 2, 3, 4, 5, 6],
#     "name": [
#         "Ivan", "Maria", "Peter",
#         "Anna", "Georgi", "Elena"
#     ],
#     "department_id": [
#         10, 20, 10, 30, 40, 20
#     ],
#     "salary": [
#         2500, 3200, 2800,
#         2100, 4000, 3500
#     ]
# })
#
# departments = pd.DataFrame({
#     "department_id": [10, 20, 30, 50],
#     "department": [
#         "IT", "HR", "Marketing", "Finance"
#     ],
#     "location": [
#         "Sofia", "Sofia", "Plovdiv", "Varna"
#     ]
# })
# ```
#
# Do a `merge()` between:
# - employees
# - departments
#
# using:
# `on="department_id"` and `how="left"`
#
# and see the result. Check what happens to Georgi.

# %%
employees = pd.DataFrame({
    "employee_id": [1, 2, 3, 4, 5, 6],
    "name": [
        "Ivan", "Maria", "Peter",
        "Anna", "Georgi", "Elena"
    ],
    "department_id": [
        10, 20, 10, 30, 40, 20
    ],
    "salary": [
        2500, 3200, 2800,
        2100, 4000, 3500
    ]
})

departments = pd.DataFrame({
    "department_id": [10, 20, 30, 50],
    "department": [
        "IT", "HR", "Marketing", "Finance"
    ],
    "location": [
        "Sofia", "Sofia", "Plovdiv", "Varna"
    ]
})

left_join = employees.merge(
    departments,
    how="left",
    on="department_id"
)

left_join

# %% [markdown]
# ## Task 70
#
# Given:
# ```python
# employees = pd.DataFrame({
#     "employee_id": [1, 2, 3, 4, 5, 6],
#     "name": [
#         "Ivan", "Maria", "Peter",
#         "Anna", "Georgi", "Elena"
#     ],
#     "department_id": [
#         10, 20, 10, 30, 40, 20
#     ],
#     "salary": [
#         2500, 3200, 2800,
#         2100, 4000, 3500
#     ]
# })
#
# departments = pd.DataFrame({
#     "department_id": [10, 20, 30, 50],
#     "department": [
#         "IT", "HR", "Marketing", "Finance"
#     ],
#     "location": [
#         "Sofia", "Sofia", "Plovdiv", "Varna"
#     ]
# })
# ```
#
# Do a `merge()` between:
# - employees
# - departments
#
# using:
# `on="department_id"` and `how="right"`
#
# and see the result. Check what happens with department_id = 50.

# %%
employees = pd.DataFrame({
    "employee_id": [1, 2, 3, 4, 5, 6],
    "name": [
        "Ivan", "Maria", "Peter",
        "Anna", "Georgi", "Elena"
    ],
    "department_id": [
        10, 20, 10, 30, 40, 20
    ],
    "salary": [
        2500, 3200, 2800,
        2100, 4000, 3500
    ]
})

departments = pd.DataFrame({
    "department_id": [10, 20, 30, 50],
    "department": [
        "IT", "HR", "Marketing", "Finance"
    ],
    "location": [
        "Sofia", "Sofia", "Plovdiv", "Varna"
    ]
})

right_join = employees.merge(
    departments,
    how="right",
    on="department_id"
)

right_join

# %% [markdown]
# ## Task 71
#
# Given:
# ```python
# employees = pd.DataFrame({
#     "employee_id": [1, 2, 3, 4, 5, 6],
#     "name": [
#         "Ivan", "Maria", "Peter",
#         "Anna", "Georgi", "Elena"
#     ],
#     "department_id": [
#         10, 20, 10, 30, 40, 20
#     ],
#     "salary": [
#         2500, 3200, 2800,
#         2100, 4000, 3500
#     ]
# })
#
# departments = pd.DataFrame({
#     "department_id": [10, 20, 30, 50],
#     "department": [
#         "IT", "HR", "Marketing", "Finance"
#     ],
#     "location": [
#         "Sofia", "Sofia", "Plovdiv", "Varna"
#     ]
# })
# ```
#
# Do a `merge()` between:
# - employees
# - departments
#
# using:
# `on="department_id"` and `how="outer"`
#
# and see the result. Here you should see both types of mismatches:
# - employee → no department
# - department → no employee

# %%
employees = pd.DataFrame({
    "employee_id": [1, 2, 3, 4, 5, 6],
    "name": [
        "Ivan", "Maria", "Peter",
        "Anna", "Georgi", "Elena"
    ],
    "department_id": [
        10, 20, 10, 30, 40, 20
    ],
    "salary": [
        2500, 3200, 2800,
        2100, 4000, 3500
    ]
})

departments = pd.DataFrame({
    "department_id": [10, 20, 30, 50],
    "department": [
        "IT", "HR", "Marketing", "Finance"
    ],
    "location": [
        "Sofia", "Sofia", "Plovdiv", "Varna"
    ]
})

outer_join = employees.merge(
    departments,
    how="outer",
    on="department_id"
)

outer_join

# %% [markdown]
# ## Task 72
#
# Given:
# ```python
# employees = pd.DataFrame({
#     "employee_id": [1, 2, 3, 4, 5, 6],
#     "name": [
#         "Ivan", "Maria", "Peter",
#         "Anna", "Georgi", "Elena"
#     ],
#     "department_id": [
#         10, 20, 10, 30, 40, 20
#     ],
#     "salary": [
#         2500, 3200, 2800,
#         2100, 4000, 3500
#     ]
# })
# ```
#
# Do a left merge so that you get a table:
# - name
# - salary
# - department
# - location
#
# Then sort the employees by:
# - salary descending

# %%
employees = pd.DataFrame({
    "employee_id": [1, 2, 3, 4, 5, 6],
    "name": [
        "Ivan", "Maria", "Peter",
        "Anna", "Georgi", "Elena"
    ],
    "department_id": [
        10, 20, 10, 30, 40, 20
    ],
    "salary": [
        2500, 3200, 2800,
        2100, 4000, 3500
    ]
})

departments = pd.DataFrame({
    "department_id": [10, 20, 30, 50],
    "department": [
        "IT", "HR", "Marketing", "Finance"
    ],
    "location": [
        "Sofia", "Sofia", "Plovdiv", "Varna"
    ]
})

result = employees.merge(departments, how="left", on="department_id")[["name", "salary", "department", "location"]]
result.sort_values(by="salary", ascending=False, inplace=True)
result

# %% [markdown]
# ## Task 73
#
# Given:
# ```python
# employees = pd.DataFrame({
#     "employee_id": [1, 2, 3, 4, 5, 6],
#     "name": [
#         "Ivan", "Maria", "Peter",
#         "Anna", "Georgi", "Elena"
#     ],
#     "department_id": [
#         10, 20, 10, 30, 40, 20
#     ],
#     "salary": [
#         2500, 3200, 2800,
#         2100, 4000, 3500
#     ]
# })
# ```
#
# Create a copy:
#
# ```python
# departments_2 = departments.rename(
# columns={"department_id": "dept_id"}
# )
# ```
#
# Now do a merge between:
#
# ```text
# employees.department_id
# departments_2.dept_id
# ```
# Here you should use:
#
# ```text
# left_on=
# right_on=
# ```

# %%
employees = pd.DataFrame({
    "employee_id": [1, 2, 3, 4, 5, 6],
    "name": [
        "Ivan", "Maria", "Peter",
        "Anna", "Georgi", "Elena"
    ],
    "department_id": [
        10, 20, 10, 30, 40, 20
    ],
    "salary": [
        2500, 3200, 2800,
        2100, 4000, 3500
    ]
})

departments_2 = departments.rename(
columns={"department_id": "dept_id"}
)

result = employees.merge(
    departments_2,
    left_on="department_id",
    right_on="dept_id"
    )

result

# %% [markdown]
# # Task 74
#
# Given:
# ```python
# employees_1 = pd.DataFrame({
# "name": ["Ivan", "Maria", "Peter"],
# "salary": [2500, 3200, 2800]
# })
#
# employees_2 = pd.DataFrame({
# "name": ["Anna", "Georgi", "Elena"],
# "salary": [2100, 4000, 3500]
# })
# ```
#
# Use `concat()` so that you get one DataFrame with all 6 employees.
# The index should be:
# ```text
# 0
# 1
# 2
# 3
# 4
# 5
# ```

# %%
employees_1 = pd.DataFrame({
"name": ["Ivan", "Maria", "Peter"],
"salary": [2500, 3200, 2800]
})

employees_2 = pd.DataFrame({
"name": ["Anna", "Georgi", "Elena"],
"salary": [2100, 4000, 3500]
})

pd.concat([employees_1, employees_2], ignore_index=True)

# %% [markdown]
# # Task 75
#
# Given:
# ```python
# names = pd.DataFrame({
# "name": ["Ivan", "Maria", "Peter"]
# })
#
# salaries = pd.DataFrame({
# "salary": [2500, 3200, 2800]
# })
# ```
#
# Use `concat()` to create a dataset about every employee and his salary:
#
# ```text
# name salary
# 0 Ivan 2500
# 1 Maria 3200
# 2 Peter 2800
# ```

# %%
names = pd.DataFrame({
"name": ["Ivan", "Maria", "Peter"]
})

salaries = pd.DataFrame({
"salary": [2500, 3200, 2800]
})

pd.concat([names, salaries], axis=1)

# %% [markdown]
# ## Task 76
#
# Given:
# ```python
# employees_basic = pd.DataFrame({
# "name": ["Ivan", "Maria"],
# "salary": [2500, 3200]
# })
#
# employees_extra = pd.DataFrame({
# "name": ["Peter", "Anna"],
# "department": ["IT", "HR"]
# })
# ```
# Use `concat()` so that you get all employees and all columns.
#
# What will appear in the places where data is missing?
# What will happen if you use `inner` join ?

# %%
employees_basic = pd.DataFrame({
"name": ["Ivan", "Maria"],
"salary": [2500, 3200]
})

employees_extra = pd.DataFrame({
"name": ["Peter", "Anna"],
"department": ["IT", "HR"]
})

pd.concat([employees_basic, employees_extra], join="outer", ignore_index=True)
pd.concat([employees_basic, employees_extra], join="inner", ignore_index=True)

# %% [markdown]
# # Task 77
#
# Given:
# ```python
# employees_january = pd.DataFrame({
#     "employee_id": [1, 2, 3],
#     "name": ["Ivan", "Maria", "Peter"],
#     "salary": [2500, 3200, 2800]
# })
#
# employees_february = pd.DataFrame({
#     "employee_id": [4, 5, 6],
#     "name": ["Anna", "Georgi", "Elena"],
#     "salary": [2100, 4000, 3500]
# })
# ```
#
# Create a DataFrame `all_employees` that contains all employees.
# Then:
# - Use ignore_index=True.
# - Sort by salary in descending order.
# - Calculate the average salary.

# %%
employees_january = pd.DataFrame({
    "employee_id": [1, 2, 3],
    "name": ["Ivan", "Maria", "Peter"],
    "salary": [2500, 3200, 2800]
})

employees_february = pd.DataFrame({
    "employee_id": [4, 5, 6],
    "name": ["Anna", "Georgi", "Elena"],
    "salary": [2100, 4000, 3500]
})

all_employees = pd.concat([employees_january, employees_february], ignore_index=True).sort_values("salary", ascending=False)
all_employees["salary"].mean()

# %% [markdown]
# # Task 78
#
# Given:
# ```python
# it = pd.DataFrame({
#     "name": ["Ivan", "Peter", "Georgi"],
#     "salary": [2500, 2800, 4000],
#     "department": ["IT", "IT", "IT"]
# })
#
# hr = pd.DataFrame({
#     "name": ["Maria", "Anna", "Elena"],
#     "salary": [3200, 2100, 3500],
#     "department": ["HR", "HR", "HR"]
# })
# ```
#
# Create a DataFrame `employees` that contains all employees.
#
# Then find:
# - the total number of employees
# - the average salary
# - the highest salary
# - the number of employees in each department
# - the average salary by department

# %%
it = pd.DataFrame({
    "name": ["Ivan", "Peter", "Georgi"],
    "salary": [2500, 2800, 4000],
    "department": ["IT", "IT", "IT"]
})

hr = pd.DataFrame({
    "name": ["Maria", "Anna", "Elena"],
    "salary": [3200, 2100, 3500],
    "department": ["HR", "HR", "HR"]
})

employees = pd.concat([it, hr], ignore_index=True)
len(employees)
employees["salary"].mean()
employees["salary"].max()
employees.groupby("department").size()
employees.groupby("department")["salary"].mean()

# %% [markdown]
# # Task 79
#
# Given:
# ```python
# employees = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena",
#              "Dimitar", "Nina", "Alex", "Laura"],
#     "department": ["IT", "IT", "HR", "HR", "Sales", "Sales",
#                    "IT", "HR", "Sales", "IT"],
#     "gender": ["M", "F", "M", "F", "M", "F", "M", "F", "M", "F"],
#     "salary": [3000, 3500, 2800, 3200, 2500, 2900,
#                3300, 3100, 2700, 3600],
#     "years_experience": [2, 5, 1, 6, 2, 4, 4, 5, 3, 7]
# })
# ```
# Create a pivot table that shows the average salary for each department

# %%
employees = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena",
             "Dimitar", "Nina", "Alex", "Laura"],
    "department": ["IT", "IT", "HR", "HR", "Sales", "Sales",
                   "IT", "HR", "Sales", "IT"],
    "gender": ["M", "F", "M", "F", "M", "F", "M", "F", "M", "F"],
    "salary": [3000, 3500, 2800, 3200, 2500, 2900,
               3300, 3100, 2700, 3600],
    "years_experience": [2, 5, 1, 6, 2, 4, 4, 5, 3, 7]
})

pd.pivot_table(employees,
               values="salary",
               index="department",
               aggfunc="mean"
             )

# %% [markdown]
# # Task 80
#
# Given:
# ```python
# employees = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena",
#              "Dimitar", "Nina", "Alex", "Laura"],
#     "department": ["IT", "IT", "HR", "HR", "Sales", "Sales",
#                    "IT", "HR", "Sales", "IT"],
#     "gender": ["M", "F", "M", "F", "M", "F", "M", "F", "M", "F"],
#     "salary": [3000, 3500, 2800, 3200, 2500, 2900,
#                3300, 3100, 2700, 3600],
#     "years_experience": [2, 5, 1, 6, 2, 4, 4, 5, 3, 7]
# })
# ```
#
# Create a pivot table that shows the average salary by `department` and `gender`

# %%
employees = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena",
             "Dimitar", "Nina", "Alex", "Laura"],
    "department": ["IT", "IT", "HR", "HR", "Sales", "Sales",
                   "IT", "HR", "Sales", "IT"],
    "gender": ["M", "F", "M", "F", "M", "F", "M", "F", "M", "F"],
    "salary": [3000, 3500, 2800, 3200, 2500, 2900,
               3300, 3100, 2700, 3600],
    "years_experience": [2, 5, 1, 6, 2, 4, 4, 5, 3, 7]
})

pd.pivot_table(employees,
               values="salary",
               index="department",
               columns="gender",
               aggfunc="mean"

)

# %% [markdown]
# # Task 81
#
# Given:
# ```python
# employees = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena",
#              "Dimitar", "Nina", "Alex", "Laura"],
#     "department": ["IT", "IT", "HR", "HR", "Sales", "Sales",
#                    "IT", "HR", "Sales", "IT"],
#     "gender": ["M", "F", "M", "F", "M", "F", "M", "F", "M", "F"],
#     "salary": [3000, 3500, 2800, 3200, 2500, 2900,
#                3300, 3100, 2700, 3600],
#     "years_experience": [2, 5, 1, 6, 2, 4, 4, 5, 3, 7]
# })
# ```
#
# Create a pivot table that shows the number of employees by `department` and `gender`

# %%
employees = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena",
             "Dimitar", "Nina", "Alex", "Laura"],
    "department": ["IT", "IT", "HR", "HR", "Sales", "Sales",
                   "IT", "HR", "Sales", "IT"],
    "gender": ["M", "F", "M", "F", "M", "F", "M", "F", "M", "F"],
    "salary": [3000, 3500, 2800, 3200, 2500, 2900,
               3300, 3100, 2700, 3600],
    "years_experience": [2, 5, 1, 6, 2, 4, 4, 5, 3, 7]
})

pd.pivot_table(employees,
               values="salary",
               index="department",
               columns="gender",
               aggfunc="count")

# %% [markdown]
# # Task 82
#
# Given:
# ```python
# employees = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena",
#              "Dimitar", "Nina", "Alex", "Laura"],
#     "department": ["IT", "IT", "HR", "HR", "Sales", "Sales",
#                    "IT", "HR", "Sales", "IT"],
#     "gender": ["M", "F", "M", "F", "M", "F", "M", "F", "M", "F"],
#     "salary": [3000, 3500, 2800, 3200, 2500, 2900,
#                3300, 3100, 2700, 3600],
#     "years_experience": [2, 5, 1, 6, 2, 4, 4, 5, 3, 7]
# })
# ```
#
# Create a pivot table that shows the total payroll (salary) by department and gender.

# %%
employees = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena",
             "Dimitar", "Nina", "Alex", "Laura"],
    "department": ["IT", "IT", "HR", "HR", "Sales", "Sales",
                   "IT", "HR", "Sales", "IT"],
    "gender": ["M", "F", "M", "F", "M", "F", "M", "F", "M", "F"],
    "salary": [3000, 3500, 2800, 3200, 2500, 2900,
               3300, 3100, 2700, 3600],
    "years_experience": [2, 5, 1, 6, 2, 4, 4, 5, 3, 7]
})

pd.pivot_table(employees,
               values="salary",
               index="department",
               columns="gender",
               aggfunc="sum",
               margins=True)

# %% [markdown]
# # Task 83
#
# Make a pivot table that shows for each department:
# - average salary
# - maximum salary
# - minimum salary

# %%
employees = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena",
             "Dimitar", "Nina", "Alex", "Laura"],
    "department": ["IT", "IT", "HR", "HR", "Sales", "Sales",
                   "IT", "HR", "Sales", "IT"],
    "gender": ["M", "F", "M", "F", "M", "F", "M", "F", "M", "F"],
    "salary": [3000, 3500, 2800, 3200, 2500, 2900,
               3300, 3100, 2700, 3600],
    "years_experience": [2, 5, 1, 6, 2, 4, 4, 5, 3, 7]
})

pd.pivot_table(
    employees,
    values="salary",
    index="department",
    aggfunc=["mean", "max", "min"]
)

# %% [markdown]
# # Task 84
#
# Given:
# ```python
# employees = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena",
#              "Dimitar", "Nina", "Alex", "Laura"],
#     "department": ["IT", "IT", "HR", "HR", "Sales", "Sales",
#                    "IT", "HR", "Sales", "IT"],
#     "gender": ["M", "F", "M", "F", "M", "F", "M", "F", "M", "F"],
#     "salary": [3000, 3500, 2800, 3200, 2500, 2900,
#                3300, 3100, 2700, 3600],
#     "years_experience": [2, 5, 1, 6, 2, 4, 4, 5, 3, 7]
# })
# ```
# Make a pivot table:
# average salary by `department` and `gender`, with missing combinations being 0 instead of NaN.

# %%
employees = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena",
             "Dimitar", "Nina", "Alex", "Laura"],
    "department": ["IT", "IT", "HR", "HR", "Sales", "Sales",
                   "IT", "HR", "Sales", "IT"],
    "gender": ["M", "F", "M", "F", "M", "F", "M", "F", "M", "F"],
    "salary": [3000, 3500, 2800, 3200, 2500, 2900,
               3300, 3100, 2700, 3600],
    "years_experience": [2, 5, 1, 6, 2, 4, 4, 5, 3, 7]
})

pd.pivot_table(
    employees,
    values="salary",
    index="department",
    columns="gender",
    aggfunc="mean",
    fill_value=0
)

# %% [markdown]
# # Task 85
#
# Given:
# ```python
# employees = pd.DataFrame({
#     "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena",
#              "Dimitar", "Nina", "Alex", "Laura"],
#     "department": ["IT", "IT", "HR", "HR", "Sales", "Sales",
#                    "IT", "HR", "Sales", "IT"],
#     "gender": ["M", "F", "M", "F", "M", "F", "M", "F", "M", "F"],
#     "salary": [3000, 3500, 2800, 3200, 2500, 2900,
#                3300, 3100, 2700, 3600],
#     "years_experience": [2, 5, 1, 6, 2, 4, 4, 5, 3, 7]
# })
# ```
#
# Make a pivot table that shows:
# average salary and average years of experience by department and gender.

# %%
employees = pd.DataFrame({
    "name": ["Ivan", "Maria", "Peter", "Anna", "Georgi", "Elena",
             "Dimitar", "Nina", "Alex", "Laura"],
    "department": ["IT", "IT", "HR", "HR", "Sales", "Sales",
                   "IT", "HR", "Sales", "IT"],
    "gender": ["M", "F", "M", "F", "M", "F", "M", "F", "M", "F"],
    "salary": [3000, 3500, 2800, 3200, 2500, 2900,
               3300, 3100, 2700, 3600],
    "years_experience": [2, 5, 1, 6, 2, 4, 4, 5, 3, 7]
})

pd.pivot_table(
    employees,
    values=["salary", "years_experience"],
    index="department",
    columns="gender",
    aggfunc="mean"
    )

# %% [markdown]
# # Task 86
#
# Given:
# ```python
# orders = pd.DataFrame({
#     "order_id": [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008,
#                  1009, 1010, 1011, 1012, 1013, 1014, 1015],
#
#     "customer": [
#         "Ivan", "Maria", "Peter", "Anna", "Georgi",
#         "Elena", "Ivan", "Maria", "Peter", "Anna",
#         "Georgi", "Elena", "Ivan", "Peter", "Maria"
#     ],
#
#     "order_date": [
#         "2026-01-15",
#         "2026-01-22",
#         "2026-02-05",
#         "2026-02-18",
#         "2026-03-03",
#         "2026-03-21",
#         "2026-04-10",
#         "2026-04-25",
#         "2026-05-08",
#         "2026-05-19",
#         "2026-06-02",
#         "2026-06-17",
#         "2026-07-04",
#         "2026-08-12",
#         "2026-09-01"
#     ],
#
#     "delivery_date": [
#         "2026-01-18",
#         "2026-01-27",
#         "2026-02-08",
#         "2026-02-22",
#         "2026-03-07",
#         "2026-03-25",
#         "2026-04-14",
#         "2026-04-29",
#         "2026-05-12",
#         "2026-05-23",
#         "2026-06-06",
#         "2026-06-20",
#         "2026-07-08",
#         "2026-08-16",
#         "2026-09-05"
#     ],
#
#     "category": [
#         "Electronics", "Clothing", "Electronics", "Books", "Clothing",
#         "Electronics", "Books", "Clothing", "Electronics", "Books",
#         "Clothing", "Electronics", "Books", "Electronics", "Clothing"
#     ],
#
#     "amount": [
#         120, 80, 250, 45, 110,
#         320, 60, 95, 180, 70,
#         130, 290, 55, 410, 100
#     ]
# })
# ```
#
# - Convert both `order_date` and `delivery_date` to Pandas datetime. Then check the DataFrame's dtypes.
# - Create three new columns based on `order_date`:
#
# ```text
# year
# month
# day
# ```
#
# - Create a column `day_name` containing the name of the weekday on which the order was placed.
# - Create a column `month_name` containing the name of the month on which the order was placed.
# - Create a new column `delivery_days` containing the number of days between order_date and delivery_date.

# %%
orders = pd.DataFrame({
    "order_id": [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008,
                 1009, 1010, 1011, 1012, 1013, 1014, 1015],
    
    "customer": [
        "Ivan", "Maria", "Peter", "Anna", "Georgi",
        "Elena", "Ivan", "Maria", "Peter", "Anna",
        "Georgi", "Elena", "Ivan", "Peter", "Maria"
    ],
    
    "order_date": [
        "2026-01-15",
        "2026-01-22",
        "2026-02-05",
        "2026-02-18",
        "2026-03-03",
        "2026-03-21",
        "2026-04-10",
        "2026-04-25",
        "2026-05-08",
        "2026-05-19",
        "2026-06-02",
        "2026-06-17",
        "2026-07-04",
        "2026-08-12",
        "2026-09-01"
    ],
    
    "delivery_date": [
        "2026-01-18",
        "2026-01-27",
        "2026-02-08",
        "2026-02-22",
        "2026-03-07",
        "2026-03-25",
        "2026-04-14",
        "2026-04-29",
        "2026-05-12",
        "2026-05-23",
        "2026-06-06",
        "2026-06-20",
        "2026-07-08",
        "2026-08-16",
        "2026-09-05"
    ],
    
    "category": [
        "Electronics", "Clothing", "Electronics", "Books", "Clothing",
        "Electronics", "Books", "Clothing", "Electronics", "Books",
        "Clothing", "Electronics", "Books", "Electronics", "Clothing"
    ],
    
    "amount": [
        120, 80, 250, 45, 110,
        320, 60, 95, 180, 70,
        130, 290, 55, 410, 100
    ]
})

orders["order_date"] = pd.to_datetime(orders["order_date"])
orders["delivery_date"] = pd.to_datetime(orders["delivery_date"])

print(orders["order_date"].dtype)
print(orders["delivery_date"].dtype)

orders["order_date_year"] = orders["order_date"].dt.year
orders["order_date_month"] = orders["order_date"].dt.month
orders["order_date_day"] = orders["order_date"].dt.day

orders["day_name"] = orders["order_date"].dt.day_name()
orders["month_name"] = orders["order_date"].dt.month_name()
orders["delivery_days"] = orders["delivery_date"] - orders["order_date"]

orders

# %% [markdown]
# # Task 87
#
# Given:
# ```python
# orders = pd.DataFrame({
#     "order_id": [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008,
#                  1009, 1010, 1011, 1012, 1013, 1014, 1015],
#
#     "customer": [
#         "Ivan", "Maria", "Peter", "Anna", "Georgi",
#         "Elena", "Ivan", "Maria", "Peter", "Anna",
#         "Georgi", "Elena", "Ivan", "Peter", "Maria"
#     ],
#
#     "order_date": [
#         "2026-01-15",
#         "2026-01-22",
#         "2026-02-05",
#         "2026-02-18",
#         "2026-03-03",
#         "2026-03-21",
#         "2026-04-10",
#         "2026-04-25",
#         "2026-05-08",
#         "2026-05-19",
#         "2026-06-02",
#         "2026-06-17",
#         "2026-07-04",
#         "2026-08-12",
#         "2026-09-01"
#     ],
#
#     "delivery_date": [
#         "2026-01-18",
#         "2026-01-27",
#         "2026-02-08",
#         "2026-02-22",
#         "2026-03-07",
#         "2026-03-25",
#         "2026-04-14",
#         "2026-04-29",
#         "2026-05-12",
#         "2026-05-23",
#         "2026-06-06",
#         "2026-06-20",
#         "2026-07-08",
#         "2026-08-16",
#         "2026-09-05"
#     ],
#
#     "category": [
#         "Electronics", "Clothing", "Electronics", "Books", "Clothing",
#         "Electronics", "Books", "Clothing", "Electronics", "Books",
#         "Clothing", "Electronics", "Books", "Electronics", "Clothing"
#     ],
#
#     "amount": [
#         120, 80, 250, 45, 110,
#         320, 60, 95, 180, 70,
#         130, 290, 55, 410, 100
#     ]
# })
# ```
#
# Find all orders placed after March 1, 2026.

# %%
orders = pd.DataFrame({
    "order_id": [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008,
                 1009, 1010, 1011, 1012, 1013, 1014, 1015],
    
    "customer": [
        "Ivan", "Maria", "Peter", "Anna", "Georgi",
        "Elena", "Ivan", "Maria", "Peter", "Anna",
        "Georgi", "Elena", "Ivan", "Peter", "Maria"
    ],
    
    "order_date": [
        "2026-01-15",
        "2026-01-22",
        "2026-02-05",
        "2026-02-18",
        "2026-03-03",
        "2026-03-21",
        "2026-04-10",
        "2026-04-25",
        "2026-05-08",
        "2026-05-19",
        "2026-06-02",
        "2026-06-17",
        "2026-07-04",
        "2026-08-12",
        "2026-09-01"
    ],
    
    "delivery_date": [
        "2026-01-18",
        "2026-01-27",
        "2026-02-08",
        "2026-02-22",
        "2026-03-07",
        "2026-03-25",
        "2026-04-14",
        "2026-04-29",
        "2026-05-12",
        "2026-05-23",
        "2026-06-06",
        "2026-06-20",
        "2026-07-08",
        "2026-08-16",
        "2026-09-05"
    ],
    
    "category": [
        "Electronics", "Clothing", "Electronics", "Books", "Clothing",
        "Electronics", "Books", "Clothing", "Electronics", "Books",
        "Clothing", "Electronics", "Books", "Electronics", "Clothing"
    ],
    
    "amount": [
        120, 80, 250, 45, 110,
        320, 60, 95, 180, 70,
        130, 290, 55, 410, 100
    ]
})

orders[orders["order_date"] > "2026-03-01"]

# %% [markdown]
# # Task 88
#
# Given:
# ```python
# orders = pd.DataFrame({
#     "order_id": [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008,
#                  1009, 1010, 1011, 1012, 1013, 1014, 1015],
#
#     "customer": [
#         "Ivan", "Maria", "Peter", "Anna", "Georgi",
#         "Elena", "Ivan", "Maria", "Peter", "Anna",
#         "Georgi", "Elena", "Ivan", "Peter", "Maria"
#     ],
#
#     "order_date": [
#         "2026-01-15",
#         "2026-01-22",
#         "2026-02-05",
#         "2026-02-18",
#         "2026-03-03",
#         "2026-03-21",
#         "2026-04-10",
#         "2026-04-25",
#         "2026-05-08",
#         "2026-05-19",
#         "2026-06-02",
#         "2026-06-17",
#         "2026-07-04",
#         "2026-08-12",
#         "2026-09-01"
#     ],
#
#     "delivery_date": [
#         "2026-01-18",
#         "2026-01-27",
#         "2026-02-08",
#         "2026-02-22",
#         "2026-03-07",
#         "2026-03-25",
#         "2026-04-14",
#         "2026-04-29",
#         "2026-05-12",
#         "2026-05-23",
#         "2026-06-06",
#         "2026-06-20",
#         "2026-07-08",
#         "2026-08-16",
#         "2026-09-05"
#     ],
#
#     "category": [
#         "Electronics", "Clothing", "Electronics", "Books", "Clothing",
#         "Electronics", "Books", "Clothing", "Electronics", "Books",
#         "Clothing", "Electronics", "Books", "Electronics", "Clothing"
#     ],
#
#     "amount": [
#         120, 80, 250, 45, 110,
#         320, 60, 95, 180, 70,
#         130, 290, 55, 410, 100
#     ]
# })
# ```
#
# Find all orders placed during April by using .dt.month.

# %%
orders = pd.DataFrame({
    "order_id": [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008,
                 1009, 1010, 1011, 1012, 1013, 1014, 1015],
    
    "customer": [
        "Ivan", "Maria", "Peter", "Anna", "Georgi",
        "Elena", "Ivan", "Maria", "Peter", "Anna",
        "Georgi", "Elena", "Ivan", "Peter", "Maria"
    ],
    
    "order_date": [
        "2026-01-15",
        "2026-01-22",
        "2026-02-05",
        "2026-02-18",
        "2026-03-03",
        "2026-03-21",
        "2026-04-10",
        "2026-04-25",
        "2026-05-08",
        "2026-05-19",
        "2026-06-02",
        "2026-06-17",
        "2026-07-04",
        "2026-08-12",
        "2026-09-01"
    ],
    
    "delivery_date": [
        "2026-01-18",
        "2026-01-27",
        "2026-02-08",
        "2026-02-22",
        "2026-03-07",
        "2026-03-25",
        "2026-04-14",
        "2026-04-29",
        "2026-05-12",
        "2026-05-23",
        "2026-06-06",
        "2026-06-20",
        "2026-07-08",
        "2026-08-16",
        "2026-09-05"
    ],
    
    "category": [
        "Electronics", "Clothing", "Electronics", "Books", "Clothing",
        "Electronics", "Books", "Clothing", "Electronics", "Books",
        "Clothing", "Electronics", "Books", "Electronics", "Clothing"
    ],
    
    "amount": [
        120, 80, 250, 45, 110,
        320, 60, 95, 180, 70,
        130, 290, 55, 410, 100
    ]
})

orders["order_date"] = pd.to_datetime(orders["order_date"])
orders[orders["order_date"].dt.month == 4]

# %% [markdown]
# # Task 89
#
# Given:
# ```python
# orders = pd.DataFrame({
#     "order_id": [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008,
#                  1009, 1010, 1011, 1012, 1013, 1014, 1015],
#
#     "customer": [
#         "Ivan", "Maria", "Peter", "Anna", "Georgi",
#         "Elena", "Ivan", "Maria", "Peter", "Anna",
#         "Georgi", "Elena", "Ivan", "Peter", "Maria"
#     ],
#
#     "order_date": [
#         "2026-01-15",
#         "2026-01-22",
#         "2026-02-05",
#         "2026-02-18",
#         "2026-03-03",
#         "2026-03-21",
#         "2026-04-10",
#         "2026-04-25",
#         "2026-05-08",
#         "2026-05-19",
#         "2026-06-02",
#         "2026-06-17",
#         "2026-07-04",
#         "2026-08-12",
#         "2026-09-01"
#     ],
#
#     "delivery_date": [
#         "2026-01-18",
#         "2026-01-27",
#         "2026-02-08",
#         "2026-02-22",
#         "2026-03-07",
#         "2026-03-25",
#         "2026-04-14",
#         "2026-04-29",
#         "2026-05-12",
#         "2026-05-23",
#         "2026-06-06",
#         "2026-06-20",
#         "2026-07-08",
#         "2026-08-16",
#         "2026-09-05"
#     ],
#
#     "category": [
#         "Electronics", "Clothing", "Electronics", "Books", "Clothing",
#         "Electronics", "Books", "Clothing", "Electronics", "Books",
#         "Clothing", "Electronics", "Books", "Electronics", "Clothing"
#     ],
#
#     "amount": [
#         120, 80, 250, 45, 110,
#         320, 60, 95, 180, 70,
#         130, 290, 55, 410, 100
#     ]
# })
# ```
#
# Find all orders placed between `2026-03-01` and `2026-05-31` including both dates.

# %%
orders = pd.DataFrame({
    "order_id": [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008,
                 1009, 1010, 1011, 1012, 1013, 1014, 1015],
    
    "customer": [
        "Ivan", "Maria", "Peter", "Anna", "Georgi",
        "Elena", "Ivan", "Maria", "Peter", "Anna",
        "Georgi", "Elena", "Ivan", "Peter", "Maria"
    ],
    
    "order_date": [
        "2026-01-15",
        "2026-01-22",
        "2026-02-05",
        "2026-02-18",
        "2026-03-03",
        "2026-03-21",
        "2026-04-10",
        "2026-04-25",
        "2026-05-08",
        "2026-05-19",
        "2026-06-02",
        "2026-06-17",
        "2026-07-04",
        "2026-08-12",
        "2026-09-01"
    ],
    
    "delivery_date": [
        "2026-01-18",
        "2026-01-27",
        "2026-02-08",
        "2026-02-22",
        "2026-03-07",
        "2026-03-25",
        "2026-04-14",
        "2026-04-29",
        "2026-05-12",
        "2026-05-23",
        "2026-06-06",
        "2026-06-20",
        "2026-07-08",
        "2026-08-16",
        "2026-09-05"
    ],
    
    "category": [
        "Electronics", "Clothing", "Electronics", "Books", "Clothing",
        "Electronics", "Books", "Clothing", "Electronics", "Books",
        "Clothing", "Electronics", "Books", "Electronics", "Clothing"
    ],
    
    "amount": [
        120, 80, 250, 45, 110,
        320, 60, 95, 180, 70,
        130, 290, 55, 410, 100
    ]
})

orders[(orders["order_date"] >= "2026-03-01") & (orders["order_date"] <= "2026-05-31")]

# %% [markdown]
# # Task 90
#
# Given:
# ```python
# orders = pd.DataFrame({
#     "order_id": [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008,
#                  1009, 1010, 1011, 1012, 1013, 1014, 1015],
#
#     "customer": [
#         "Ivan", "Maria", "Peter", "Anna", "Georgi",
#         "Elena", "Ivan", "Maria", "Peter", "Anna",
#         "Georgi", "Elena", "Ivan", "Peter", "Maria"
#     ],
#
#     "order_date": [
#         "2026-01-15",
#         "2026-01-22",
#         "2026-02-05",
#         "2026-02-18",
#         "2026-03-03",
#         "2026-03-21",
#         "2026-04-10",
#         "2026-04-25",
#         "2026-05-08",
#         "2026-05-19",
#         "2026-06-02",
#         "2026-06-17",
#         "2026-07-04",
#         "2026-08-12",
#         "2026-09-01"
#     ],
#
#     "delivery_date": [
#         "2026-01-18",
#         "2026-01-27",
#         "2026-02-08",
#         "2026-02-22",
#         "2026-03-07",
#         "2026-03-25",
#         "2026-04-14",
#         "2026-04-29",
#         "2026-05-12",
#         "2026-05-23",
#         "2026-06-06",
#         "2026-06-20",
#         "2026-07-08",
#         "2026-08-16",
#         "2026-09-05"
#     ],
#
#     "category": [
#         "Electronics", "Clothing", "Electronics", "Books", "Clothing",
#         "Electronics", "Books", "Clothing", "Electronics", "Books",
#         "Clothing", "Electronics", "Books", "Electronics", "Clothing"
#     ],
#
#     "amount": [
#         120, 80, 250, 45, 110,
#         320, 60, 95, 180, 70,
#         130, 290, 55, 410, 100
#     ]
# })
# ```
# - Find the order with the shortest delivery time.
# - Calculate the average delivery time across all orders.

# %%
orders = pd.DataFrame({
    "order_id": [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008,
                 1009, 1010, 1011, 1012, 1013, 1014, 1015],
    
    "customer": [
        "Ivan", "Maria", "Peter", "Anna", "Georgi",
        "Elena", "Ivan", "Maria", "Peter", "Anna",
        "Georgi", "Elena", "Ivan", "Peter", "Maria"
    ],
    
    "order_date": [
        "2026-01-15",
        "2026-01-22",
        "2026-02-05",
        "2026-02-18",
        "2026-03-03",
        "2026-03-21",
        "2026-04-10",
        "2026-04-25",
        "2026-05-08",
        "2026-05-19",
        "2026-06-02",
        "2026-06-17",
        "2026-07-04",
        "2026-08-12",
        "2026-09-01"
    ],
    
    "delivery_date": [
        "2026-01-18",
        "2026-01-27",
        "2026-02-08",
        "2026-02-22",
        "2026-03-07",
        "2026-03-25",
        "2026-04-14",
        "2026-04-29",
        "2026-05-12",
        "2026-05-23",
        "2026-06-06",
        "2026-06-20",
        "2026-07-08",
        "2026-08-16",
        "2026-09-05"
    ],
    
    "category": [
        "Electronics", "Clothing", "Electronics", "Books", "Clothing",
        "Electronics", "Books", "Clothing", "Electronics", "Books",
        "Clothing", "Electronics", "Books", "Electronics", "Clothing"
    ],
    
    "amount": [
        120, 80, 250, 45, 110,
        320, 60, 95, 180, 70,
        130, 290, 55, 410, 100
    ]
})

orders["order_date"] = pd.to_datetime(orders["order_date"])
orders["delivery_date"] = pd.to_datetime(orders["delivery_date"])

orders["delivery_period"] = orders["delivery_date"] - orders["order_date"]

orders.loc[orders["delivery_period"].idxmin()]

orders["delivery_period"].mean()

# %% [markdown]
# # Task 91
#
# Given:
# ```python
# orders = pd.DataFrame({
#     "order_id": [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008,
#                  1009, 1010, 1011, 1012, 1013, 1014, 1015],
#
#     "customer": [
#         "Ivan", "Maria", "Peter", "Anna", "Georgi",
#         "Elena", "Ivan", "Maria", "Peter", "Anna",
#         "Georgi", "Elena", "Ivan", "Peter", "Maria"
#     ],
#
#     "order_date": [
#         "2026-01-15",
#         "2026-01-22",
#         "2026-02-05",
#         "2026-02-18",
#         "2026-03-03",
#         "2026-03-21",
#         "2026-04-10",
#         "2026-04-25",
#         "2026-05-08",
#         "2026-05-19",
#         "2026-06-02",
#         "2026-06-17",
#         "2026-07-04",
#         "2026-08-12",
#         "2026-09-01"
#     ],
#
#     "delivery_date": [
#         "2026-01-18",
#         "2026-01-27",
#         "2026-02-08",
#         "2026-02-22",
#         "2026-03-07",
#         "2026-03-25",
#         "2026-04-14",
#         "2026-04-29",
#         "2026-05-12",
#         "2026-05-23",
#         "2026-06-06",
#         "2026-06-20",
#         "2026-07-08",
#         "2026-08-16",
#         "2026-09-05"
#     ],
#
#     "category": [
#         "Electronics", "Clothing", "Electronics", "Books", "Clothing",
#         "Electronics", "Books", "Clothing", "Electronics", "Books",
#         "Clothing", "Electronics", "Books", "Electronics", "Clothing"
#     ],
#
#     "amount": [
#         120, 80, 250, 45, 110,
#         320, 60, 95, 180, 70,
#         130, 290, 55, 410, 100
#     ]
# })
# ```
#
# Find how many orders were placed on each day of the week.

# %%
orders = pd.DataFrame({
    "order_id": [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008,
                 1009, 1010, 1011, 1012, 1013, 1014, 1015],
    
    "customer": [
        "Ivan", "Maria", "Peter", "Anna", "Georgi",
        "Elena", "Ivan", "Maria", "Peter", "Anna",
        "Georgi", "Elena", "Ivan", "Peter", "Maria"
    ],
    
    "order_date": [
        "2026-01-15",
        "2026-01-22",
        "2026-02-05",
        "2026-02-18",
        "2026-03-03",
        "2026-03-21",
        "2026-04-10",
        "2026-04-25",
        "2026-05-08",
        "2026-05-19",
        "2026-06-02",
        "2026-06-17",
        "2026-07-04",
        "2026-08-12",
        "2026-09-01"
    ],
    
    "delivery_date": [
        "2026-01-18",
        "2026-01-27",
        "2026-02-08",
        "2026-02-22",
        "2026-03-07",
        "2026-03-25",
        "2026-04-14",
        "2026-04-29",
        "2026-05-12",
        "2026-05-23",
        "2026-06-06",
        "2026-06-20",
        "2026-07-08",
        "2026-08-16",
        "2026-09-05"
    ],
    
    "category": [
        "Electronics", "Clothing", "Electronics", "Books", "Clothing",
        "Electronics", "Books", "Clothing", "Electronics", "Books",
        "Clothing", "Electronics", "Books", "Electronics", "Clothing"
    ],
    
    "amount": [
        120, 80, 250, 45, 110,
        320, 60, 95, 180, 70,
        130, 290, 55, 410, 100
    ]
})

orders["order_date"] = pd.to_datetime(orders["order_date"])

orders["order_date_day_of_week"] = orders["order_date"].dt.day_name()

orders.groupby("order_date_day_of_week")["order_id"].count()

# %% [markdown]
# # Task 92
#
# Given:
# ```python
# orders = pd.DataFrame({
#     "order_id": [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008,
#                  1009, 1010, 1011, 1012, 1013, 1014, 1015],
#
#     "customer": [
#         "Ivan", "Maria", "Peter", "Anna", "Georgi",
#         "Elena", "Ivan", "Maria", "Peter", "Anna",
#         "Georgi", "Elena", "Ivan", "Peter", "Maria"
#     ],
#
#     "order_date": [
#         "2026-01-15",
#         "2026-01-22",
#         "2026-02-05",
#         "2026-02-18",
#         "2026-03-03",
#         "2026-03-21",
#         "2026-04-10",
#         "2026-04-25",
#         "2026-05-08",
#         "2026-05-19",
#         "2026-06-02",
#         "2026-06-17",
#         "2026-07-04",
#         "2026-08-12",
#         "2026-09-01"
#     ],
#
#     "delivery_date": [
#         "2026-01-18",
#         "2026-01-27",
#         "2026-02-08",
#         "2026-02-22",
#         "2026-03-07",
#         "2026-03-25",
#         "2026-04-14",
#         "2026-04-29",
#         "2026-05-12",
#         "2026-05-23",
#         "2026-06-06",
#         "2026-06-20",
#         "2026-07-08",
#         "2026-08-16",
#         "2026-09-05"
#     ],
#
#     "category": [
#         "Electronics", "Clothing", "Electronics", "Books", "Clothing",
#         "Electronics", "Books", "Clothing", "Electronics", "Books",
#         "Clothing", "Electronics", "Books", "Electronics", "Clothing"
#     ],
#
#     "amount": [
#         120, 80, 250, 45, 110,
#         320, 60, 95, 180, 70,
#         130, 290, 55, 410, 100
#     ]
# })
# ```
# Calculate the average delivery_days for each product category.

# %%
orders = pd.DataFrame({
    "order_id": [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008,
                 1009, 1010, 1011, 1012, 1013, 1014, 1015],
    
    "customer": [
        "Ivan", "Maria", "Peter", "Anna", "Georgi",
        "Elena", "Ivan", "Maria", "Peter", "Anna",
        "Georgi", "Elena", "Ivan", "Peter", "Maria"
    ],
    
    "order_date": [
        "2026-01-15",
        "2026-01-22",
        "2026-02-05",
        "2026-02-18",
        "2026-03-03",
        "2026-03-21",
        "2026-04-10",
        "2026-04-25",
        "2026-05-08",
        "2026-05-19",
        "2026-06-02",
        "2026-06-17",
        "2026-07-04",
        "2026-08-12",
        "2026-09-01"
    ],
    
    "delivery_date": [
        "2026-01-18",
        "2026-01-27",
        "2026-02-08",
        "2026-02-22",
        "2026-03-07",
        "2026-03-25",
        "2026-04-14",
        "2026-04-29",
        "2026-05-12",
        "2026-05-23",
        "2026-06-06",
        "2026-06-20",
        "2026-07-08",
        "2026-08-16",
        "2026-09-05"
    ],
    
    "category": [
        "Electronics", "Clothing", "Electronics", "Books", "Clothing",
        "Electronics", "Books", "Clothing", "Electronics", "Books",
        "Clothing", "Electronics", "Books", "Electronics", "Clothing"
    ],
    
    "amount": [
        120, 80, 250, 45, 110,
        320, 60, 95, 180, 70,
        130, 290, 55, 410, 100
    ]
})

orders["order_date"] = pd.to_datetime(orders["order_date"])
orders["delivery_date"] = pd.to_datetime(orders["delivery_date"])

orders["delivery_period"] = orders["delivery_date"] - orders["order_date"]

orders.groupby("category")["delivery_period"].mean()

# %% [markdown]
# # Task 93
#
# Given:
# ```python
# orders = pd.DataFrame({
#     "order_id": [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008,
#                  1009, 1010, 1011, 1012, 1013, 1014, 1015],
#
#     "customer": [
#         "Ivan", "Maria", "Peter", "Anna", "Georgi",
#         "Elena", "Ivan", "Maria", "Peter", "Anna",
#         "Georgi", "Elena", "Ivan", "Peter", "Maria"
#     ],
#
#     "order_date": [
#         "2026-01-15",
#         "2026-01-22",
#         "2026-02-05",
#         "2026-02-18",
#         "2026-03-03",
#         "2026-03-21",
#         "2026-04-10",
#         "2026-04-25",
#         "2026-05-08",
#         "2026-05-19",
#         "2026-06-02",
#         "2026-06-17",
#         "2026-07-04",
#         "2026-08-12",
#         "2026-09-01"
#     ],
#
#     "delivery_date": [
#         "2026-01-18",
#         "2026-01-27",
#         "2026-02-08",
#         "2026-02-22",
#         "2026-03-07",
#         "2026-03-25",
#         "2026-04-14",
#         "2026-04-29",
#         "2026-05-12",
#         "2026-05-23",
#         "2026-06-06",
#         "2026-06-20",
#         "2026-07-08",
#         "2026-08-16",
#         "2026-09-05"
#     ],
#
#     "category": [
#         "Electronics", "Clothing", "Electronics", "Books", "Clothing",
#         "Electronics", "Books", "Clothing", "Electronics", "Books",
#         "Clothing", "Electronics", "Books", "Electronics", "Clothing"
#     ],
#
#     "amount": [
#         120, 80, 250, 45, 110,
#         320, 60, 95, 180, 70,
#         130, 290, 55, 410, 100
#     ]
# })
# ```
# - Calculate the total sales amount for each month.
# - Find the month with the highest total sales.

# %%
orders = pd.DataFrame({
    "order_id": [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008,
                 1009, 1010, 1011, 1012, 1013, 1014, 1015],
    
    "customer": [
        "Ivan", "Maria", "Peter", "Anna", "Georgi",
        "Elena", "Ivan", "Maria", "Peter", "Anna",
        "Georgi", "Elena", "Ivan", "Peter", "Maria"
    ],
    
    "order_date": [
        "2026-01-15",
        "2026-01-22",
        "2026-02-05",
        "2026-02-18",
        "2026-03-03",
        "2026-03-21",
        "2026-04-10",
        "2026-04-25",
        "2026-05-08",
        "2026-05-19",
        "2026-06-02",
        "2026-06-17",
        "2026-07-04",
        "2026-08-12",
        "2026-09-01"
    ],
    
    "delivery_date": [
        "2026-01-18",
        "2026-01-27",
        "2026-02-08",
        "2026-02-22",
        "2026-03-07",
        "2026-03-25",
        "2026-04-14",
        "2026-04-29",
        "2026-05-12",
        "2026-05-23",
        "2026-06-06",
        "2026-06-20",
        "2026-07-08",
        "2026-08-16",
        "2026-09-05"
    ],
    
    "category": [
        "Electronics", "Clothing", "Electronics", "Books", "Clothing",
        "Electronics", "Books", "Clothing", "Electronics", "Books",
        "Clothing", "Electronics", "Books", "Electronics", "Clothing"
    ],
    
    "amount": [
        120, 80, 250, 45, 110,
        320, 60, 95, 180, 70,
        130, 290, 55, 410, 100
    ]
})

orders["delivery_date"] = pd.to_datetime(orders["delivery_date"])
orders["delivery_month"] = orders["delivery_date"].dt.month_name()
orders.groupby("delivery_month")["amount"].sum()

orders.groupby("delivery_month")["amount"].sum().idxmax()

# %% [markdown]
# # Task 94
#
# Given:
# ```python
# orders = pd.DataFrame({
#     "order_id": [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008,
#                  1009, 1010, 1011, 1012, 1013, 1014, 1015],
#
#     "customer": [
#         "Ivan", "Maria", "Peter", "Anna", "Georgi",
#         "Elena", "Ivan", "Maria", "Peter", "Anna",
#         "Georgi", "Elena", "Ivan", "Peter", "Maria"
#     ],
#
#     "order_date": [
#         "2026-01-15",
#         "2026-01-22",
#         "2026-02-05",
#         "2026-02-18",
#         "2026-03-03",
#         "2026-03-21",
#         "2026-04-10",
#         "2026-04-25",
#         "2026-05-08",
#         "2026-05-19",
#         "2026-06-02",
#         "2026-06-17",
#         "2026-07-04",
#         "2026-08-12",
#         "2026-09-01"
#     ],
#
#     "delivery_date": [
#         "2026-01-18",
#         "2026-01-27",
#         "2026-02-08",
#         "2026-02-22",
#         "2026-03-07",
#         "2026-03-25",
#         "2026-04-14",
#         "2026-04-29",
#         "2026-05-12",
#         "2026-05-23",
#         "2026-06-06",
#         "2026-06-20",
#         "2026-07-08",
#         "2026-08-16",
#         "2026-09-05"
#     ],
#
#     "category": [
#         "Electronics", "Clothing", "Electronics", "Books", "Clothing",
#         "Electronics", "Books", "Clothing", "Electronics", "Books",
#         "Clothing", "Electronics", "Books", "Electronics", "Clothing"
#     ],
#
#     "amount": [
#         120, 80, 250, 45, 110,
#         320, 60, 95, 180, 70,
#         130, 290, 55, 410, 100
#     ]
# })
# ```
#
# - Find the average delivery time for each customer.
# - Calculate the total amount spent by each customer and find the customer who spent the most.

# %%
orders = pd.DataFrame({
    "order_id": [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008,
                 1009, 1010, 1011, 1012, 1013, 1014, 1015],
    
    "customer": [
        "Ivan", "Maria", "Peter", "Anna", "Georgi",
        "Elena", "Ivan", "Maria", "Peter", "Anna",
        "Georgi", "Elena", "Ivan", "Peter", "Maria"
    ],
    
    "order_date": [
        "2026-01-15",
        "2026-01-22",
        "2026-02-05",
        "2026-02-18",
        "2026-03-03",
        "2026-03-21",
        "2026-04-10",
        "2026-04-25",
        "2026-05-08",
        "2026-05-19",
        "2026-06-02",
        "2026-06-17",
        "2026-07-04",
        "2026-08-12",
        "2026-09-01"
    ],
    
    "delivery_date": [
        "2026-01-18",
        "2026-01-27",
        "2026-02-08",
        "2026-02-22",
        "2026-03-07",
        "2026-03-25",
        "2026-04-14",
        "2026-04-29",
        "2026-05-12",
        "2026-05-23",
        "2026-06-06",
        "2026-06-20",
        "2026-07-08",
        "2026-08-16",
        "2026-09-05"
    ],
    
    "category": [
        "Electronics", "Clothing", "Electronics", "Books", "Clothing",
        "Electronics", "Books", "Clothing", "Electronics", "Books",
        "Clothing", "Electronics", "Books", "Electronics", "Clothing"
    ],
    
    "amount": [
        120, 80, 250, 45, 110,
        320, 60, 95, 180, 70,
        130, 290, 55, 410, 100
    ]
})

orders["order_date"] = pd.to_datetime(orders["order_date"])
orders["delivery_date"] = pd.to_datetime(orders["delivery_date"])

orders["delivery_period"] = orders["delivery_date"] - orders["order_date"]

orders.groupby("customer")["delivery_period"].mean()
orders.groupby("customer")["amount"].sum().idxmax()

# %% [markdown]
# # Task 95
#
# Given:
# ```python
# orders = pd.DataFrame({
#     "order_id": [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008,
#                  1009, 1010, 1011, 1012, 1013, 1014, 1015],
#
#     "customer": [
#         "Ivan", "Maria", "Peter", "Anna", "Georgi",
#         "Elena", "Ivan", "Maria", "Peter", "Anna",
#         "Georgi", "Elena", "Ivan", "Peter", "Maria"
#     ],
#
#     "order_date": [
#         "2026-01-15",
#         "2026-01-22",
#         "2026-02-05",
#         "2026-02-18",
#         "2026-03-03",
#         "2026-03-21",
#         "2026-04-10",
#         "2026-04-25",
#         "2026-05-08",
#         "2026-05-19",
#         "2026-06-02",
#         "2026-06-17",
#         "2026-07-04",
#         "2026-08-12",
#         "2026-09-01"
#     ],
#
#     "delivery_date": [
#         "2026-01-18",
#         "2026-01-27",
#         "2026-02-08",
#         "2026-02-22",
#         "2026-03-07",
#         "2026-03-25",
#         "2026-04-14",
#         "2026-04-29",
#         "2026-05-12",
#         "2026-05-23",
#         "2026-06-06",
#         "2026-06-20",
#         "2026-07-08",
#         "2026-08-16",
#         "2026-09-05"
#     ],
#
#     "category": [
#         "Electronics", "Clothing", "Electronics", "Books", "Clothing",
#         "Electronics", "Books", "Clothing", "Electronics", "Books",
#         "Clothing", "Electronics", "Books", "Electronics", "Clothing"
#     ],
#
#     "amount": [
#         120, 80, 250, 45, 110,
#         320, 60, 95, 180, 70,
#         130, 290, 55, 410, 100
#     ]
# })
# ```
#
# Find all orders that were placed on Saturday or Sunday.

# %%
orders = pd.DataFrame({
    "order_id": [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008,
                 1009, 1010, 1011, 1012, 1013, 1014, 1015],
    
    "customer": [
        "Ivan", "Maria", "Peter", "Anna", "Georgi",
        "Elena", "Ivan", "Maria", "Peter", "Anna",
        "Georgi", "Elena", "Ivan", "Peter", "Maria"
    ],
    
    "order_date": [
        "2026-01-15",
        "2026-01-22",
        "2026-02-05",
        "2026-02-18",
        "2026-03-03",
        "2026-03-21",
        "2026-04-10",
        "2026-04-25",
        "2026-05-08",
        "2026-05-19",
        "2026-06-02",
        "2026-06-17",
        "2026-07-04",
        "2026-08-12",
        "2026-09-01"
    ],
    
    "delivery_date": [
        "2026-01-18",
        "2026-01-27",
        "2026-02-08",
        "2026-02-22",
        "2026-03-07",
        "2026-03-25",
        "2026-04-14",
        "2026-04-29",
        "2026-05-12",
        "2026-05-23",
        "2026-06-06",
        "2026-06-20",
        "2026-07-08",
        "2026-08-16",
        "2026-09-05"
    ],
    
    "category": [
        "Electronics", "Clothing", "Electronics", "Books", "Clothing",
        "Electronics", "Books", "Clothing", "Electronics", "Books",
        "Clothing", "Electronics", "Books", "Electronics", "Clothing"
    ],
    
    "amount": [
        120, 80, 250, 45, 110,
        320, 60, 95, 180, 70,
        130, 290, 55, 410, 100
    ]
})

orders["order_date"] = pd.to_datetime(orders["order_date"])
orders["day_of_week"] = orders["order_date"].dt.day_of_week
weekend_orders = orders[(orders["day_of_week"] == 5) | (orders["day_of_week"] == 6)]
weekend_orders.count()

# %% [markdown]
# # Tak 96
#
# Given:
# ```python
# orders = pd.DataFrame({
#     "order_id": [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008,
#                  1009, 1010, 1011, 1012, 1013, 1014, 1015],
#
#     "customer": [
#         "Ivan", "Maria", "Peter", "Anna", "Georgi",
#         "Elena", "Ivan", "Maria", "Peter", "Anna",
#         "Georgi", "Elena", "Ivan", "Peter", "Maria"
#     ],
#
#     "order_date": [
#         "2026-01-15",
#         "2026-01-22",
#         "2026-02-05",
#         "2026-02-18",
#         "2026-03-03",
#         "2026-03-21",
#         "2026-04-10",
#         "2026-04-25",
#         "2026-05-08",
#         "2026-05-19",
#         "2026-06-02",
#         "2026-06-17",
#         "2026-07-04",
#         "2026-08-12",
#         "2026-09-01"
#     ],
#
#     "delivery_date": [
#         "2026-01-18",
#         "2026-01-27",
#         "2026-02-08",
#         "2026-02-22",
#         "2026-03-07",
#         "2026-03-25",
#         "2026-04-14",
#         "2026-04-29",
#         "2026-05-12",
#         "2026-05-23",
#         "2026-06-06",
#         "2026-06-20",
#         "2026-07-08",
#         "2026-08-16",
#         "2026-09-05"
#     ],
#
#     "category": [
#         "Electronics", "Clothing", "Electronics", "Books", "Clothing",
#         "Electronics", "Books", "Clothing", "Electronics", "Books",
#         "Clothing", "Electronics", "Books", "Electronics", "Clothing"
#     ],
#
#     "amount": [
#         120, 80, 250, 45, 110,
#         320, 60, 95, 180, 70,
#         130, 290, 55, 410, 100
#     ]
# })
# ```
#
# Create a summary DataFrame containing, for each month:
# - number of orders
# - total sales
# - average order amount
# - average delivery time

# %%
orders = pd.DataFrame({
    "order_id": [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008,
                 1009, 1010, 1011, 1012, 1013, 1014, 1015],
    
    "customer": [
        "Ivan", "Maria", "Peter", "Anna", "Georgi",
        "Elena", "Ivan", "Maria", "Peter", "Anna",
        "Georgi", "Elena", "Ivan", "Peter", "Maria"
    ],
    
    "order_date": [
        "2026-01-15",
        "2026-01-22",
        "2026-02-05",
        "2026-02-18",
        "2026-03-03",
        "2026-03-21",
        "2026-04-10",
        "2026-04-25",
        "2026-05-08",
        "2026-05-19",
        "2026-06-02",
        "2026-06-17",
        "2026-07-04",
        "2026-08-12",
        "2026-09-01"
    ],
    
    "delivery_date": [
        "2026-01-18",
        "2026-01-27",
        "2026-02-08",
        "2026-02-22",
        "2026-03-07",
        "2026-03-25",
        "2026-04-14",
        "2026-04-29",
        "2026-05-12",
        "2026-05-23",
        "2026-06-06",
        "2026-06-20",
        "2026-07-08",
        "2026-08-16",
        "2026-09-05"
    ],
    
    "category": [
        "Electronics", "Clothing", "Electronics", "Books", "Clothing",
        "Electronics", "Books", "Clothing", "Electronics", "Books",
        "Clothing", "Electronics", "Books", "Electronics", "Clothing"
    ],
    
    "amount": [
        120, 80, 250, 45, 110,
        320, 60, 95, 180, 70,
        130, 290, 55, 410, 100
    ]
})

orders["order_date"] = pd.to_datetime(orders["order_date"])
orders["delivery_date"] = pd.to_datetime(orders["delivery_date"])
orders["delivery_time"] = (orders["delivery_date"] - orders["order_date"]).dt.days
orders["day_of_week"] = orders["order_date"].dt.day_name()
orders.groupby("day_of_week").agg(
    order_count = ("order_id", "count"),
    total_sales = ("amount", "sum"),
    avg_amount = ("amount", "mean"),
    avg_delivery_time = ("delivery_time", "mean")
)

# %% [markdown]
# # Task 97
#
# Create a small Series:
#
# ```python
# dates = pd.Series([
#     "2026-01-15",
#     "2026-02-20",
#     "invalid date",
#     "2026-04-10",
#     "not available"
# ])
# ```
#
# Convert it to datetime using `errors="coerce"`
#
# Then:
# - Find which values became NaT.
# - Count them.
# - Remove them.
# - Calculate how many valid dates remain.

# %%
dates = pd.Series([
    "2026-01-15",
    "2026-02-20",
    "invalid date",
    "2026-04-10",
    "not available"
])

dates = pd.to_datetime(dates, errors="coerce")
dates.isna().sum()
dates.notna().sum()
dates = dates.dropna()

# %% [markdown]
# # Task 98
#
# Given:
# ```python
# employees = pd.DataFrame({
#     "employee_id": [101, 102, 103, 104, 105, 106, 107, 108],
#     "name": [
#         "Ivan", "Maria", "Peter", "Anna",
#         "Georgi", "Elena", "Dimitar", "Nina"
#     ],
#     "department": [
#         "IT", "HR", "IT", "Sales",
#         "HR", "IT", "Sales", "HR"
#     ],
#     "gender": [
#         "M", "F", "M", "F",
#         "M", "F", "M", "F"
#     ],
#     "salary": [
#         3000, 3500, 2800, 2500,
#         3200, 3600, 2700, 3100
#     ],
#     "years_experience": [
#         2, 5, 1, 3,
#         4, 6, 2, 5
#     ]
# })
# ```
#
# Set `employee_id` as the index.
#
# - Display employee 104.
# - Display employees 102, 104, and 106.
# - Return employee_id back to a normal column.
# - Ascending order.
# - Descending order.
# - Select the sixth row by position

# %%
employees = pd.DataFrame({
    "employee_id": [101, 102, 103, 104, 105, 106, 107, 108],
    "name": [
        "Ivan", "Maria", "Peter", "Anna",
        "Georgi", "Elena", "Dimitar", "Nina"
    ],
    "department": [
        "IT", "HR", "IT", "Sales",
        "HR", "IT", "Sales", "HR"
    ],
    "gender": [
        "M", "F", "M", "F",
        "M", "F", "M", "F"
    ],
    "salary": [
        3000, 3500, 2800, 2500,
        3200, 3600, 2700, 3100
    ],
    "years_experience": [
        2, 5, 1, 3,
        4, 6, 2, 5
    ]
})

employees.set_index("employee_id", inplace=True)
employees.loc[104]
employees.loc[[102, 104, 106]]
employees.reset_index()
employees.sort_index()
employees.sort_index(ascending=False)
employees.iloc[6]

# %% [markdown]
# # Task 99
#
# Given:
# ```python
# employees = pd.DataFrame({
#     "employee_id": [101, 102, 103, 104, 105, 106, 107, 108],
#     "name": [
#         "Ivan", "Maria", "Peter", "Anna",
#         "Georgi", "Elena", "Dimitar", "Nina"
#     ],
#     "department": [
#         "IT", "HR", "IT", "Sales",
#         "HR", "IT", "Sales", "HR"
#     ],
#     "gender": [
#         "M", "F", "M", "F",
#         "M", "F", "M", "F"
#     ],
#     "salary": [
#         3000, 3500, 2800, 2500,
#         3200, 3600, 2700, 3100
#     ],
#     "years_experience": [
#         2, 5, 1, 3,
#         4, 6, 2, 5
#     ]
# })
# ```
#
# Using the original DataFrame:
#
# 1. Find all employees with `salary > 3000`
# 2. Then reset the index so that the resulting DataFrame has:
#
# ```text
# 0
# 1
# 2
# ...
#
# instead of the original index.
# ```

# %%
employees = pd.DataFrame({
    "employee_id": [101, 102, 103, 104, 105, 106, 107, 108],
    "name": [
        "Ivan", "Maria", "Peter", "Anna",
        "Georgi", "Elena", "Dimitar", "Nina"
    ],
    "department": [
        "IT", "HR", "IT", "Sales",
        "HR", "IT", "Sales", "HR"
    ],
    "gender": [
        "M", "F", "M", "F",
        "M", "F", "M", "F"
    ],
    "salary": [
        3000, 3500, 2800, 2500,
        3200, 3600, 2700, 3100
    ],
    "years_experience": [
        2, 5, 1, 3,
        4, 6, 2, 5
    ]
})

employees[employees["salary"] > 3000].reset_index(drop=True)

# %% [markdown]
# # Task 100
#
# Given:
# ```python
# orders = pd.DataFrame({
#     "order_date": [
#         "2026-01-15",
#         "2026-02-20",
#         "2026-03-10",
#         "2026-04-05",
#         "2026-05-18"
#     ],
#     "customer": [
#         "Ivan", "Maria", "Peter", "Anna", "Georgi"
#     ],
#     "amount": [
#         120, 250, 180, 90, 310
#     ]
# })
# ```
#
# Convert `order_date` to datetime and make it the index.
# Then:
# - Select the order from 2026-03-10.
# - Sort the DataFrame by the date index.
# -  Select orders after 2026-02-01.

# %%
orders = pd.DataFrame({
    "order_date": [
        "2026-01-15",
        "2026-02-20",
        "2026-03-10",
        "2026-04-05",
        "2026-05-18"
    ],
    "customer": [
        "Ivan", "Maria", "Peter", "Anna", "Georgi"
    ],
    "amount": [
        120, 250, 180, 90, 310
    ]
})

orders["order_date"] = pd.to_datetime(orders["order_date"])
orders.set_index("order_date", inplace=True)
orders.loc["2026-03-10"]
orders.sort_index(inplace=True)
orders[orders.index > "2026-02-01"]

# %% [markdown]
# # Task 101
#
# Given:
# ```python
# employees = pd.DataFrame({
#     "employee_id": [101, 102, 103, 104, 105, 106, 107, 108],
#     "name": [
#         "Ivan", "Maria", "Peter", "Anna",
#         "Georgi", "Elena", "Dimitar", "Nina"
#     ],
#     "department": [
#         "IT", "HR", "IT", "Sales",
#         "HR", "IT", "Sales", "HR"
#     ],
#     "gender": [
#         "M", "F", "M", "F",
#         "M", "F", "M", "F"
#     ],
#     "salary": [
#         3000, 3500, 2800, 2500,
#         3200, 3600, 2700, 3100
#     ],
#     "years_experience": [
#         2, 5, 1, 3,
#         4, 6, 2, 5
#     ]
# })
# ```
#
# Set both `department` and `gender` as the index.
# Then:
# - Display the entire DataFrame.
# - Display all IT employees.
# - Display the IT male employee.
# - Display the following combinations:
#     - IT + M
#     - HR + F
#     - Sales + M
# - Take your MultiIndex DataFrame and convert it back into a normal DataFrame.

# %%
employees = pd.DataFrame({
    "employee_id": [101, 102, 103, 104, 105, 106, 107, 108],
    "name": [
        "Ivan", "Maria", "Peter", "Anna",
        "Georgi", "Elena", "Dimitar", "Nina"
    ],
    "department": [
        "IT", "HR", "IT", "Sales",
        "HR", "IT", "Sales", "HR"
    ],
    "gender": [
        "M", "F", "M", "F",
        "M", "F", "M", "F"
    ],
    "salary": [
        3000, 3500, 2800, 2500,
        3200, 3600, 2700, 3100
    ],
    "years_experience": [
        2, 5, 1, 3,
        4, 6, 2, 5
    ]
})

employees.set_index(["department", "gender"], inplace=True)
employees.sort_index(level="department")
employees.loc["IT"]
employees.loc[("IT", "M")]
employees.loc[
    [
        ("IT", "M"),
        ("HR", "F"),
        ("Sales", "M")
    ]
]
employees.reset_index()

# %% [markdown]
# # Task 102
#
# Given:
# ```python
# employees = pd.DataFrame({
#     "employee_id": [101, 102, 103, 104, 105, 106, 107, 108],
#     "name": [
#         "Ivan", "Maria", "Peter", "Anna",
#         "Georgi", "Elena", "Dimitar", "Nina"
#     ],
#     "department": [
#         "IT", "HR", "IT", "Sales",
#         "HR", "IT", "Sales", "HR"
#     ],
#     "gender": [
#         "M", "F", "M", "F",
#         "M", "F", "M", "F"
#     ],
#     "salary": [
#         3000, 3500, 2800, 2500,
#         3200, 3600, 2700, 3100
#     ],
#     "years_experience": [
#         2, 5, 1, 3,
#         4, 6, 2, 5
#     ]
# })
# ```
# Calculate the average salary by department and gender.
#
# Expected structure:
#
# department  gender
# HR          F          ...
#             M          ...
# IT          F          ...
#             M          ...
# Sales       F          ...
#             M          ...
#
# Then convert the result into a normal DataFrame.

# %%
employees = pd.DataFrame({
    "employee_id": [101, 102, 103, 104, 105, 106, 107, 108],
    "name": [
        "Ivan", "Maria", "Peter", "Anna",
        "Georgi", "Elena", "Dimitar", "Nina"
    ],
    "department": [
        "IT", "HR", "IT", "Sales",
        "HR", "IT", "Sales", "HR"
    ],
    "gender": [
        "M", "F", "M", "F",
        "M", "F", "M", "F"
    ],
    "salary": [
        3000, 3500, 2800, 2500,
        3200, 3600, 2700, 3100
    ],
    "years_experience": [
        2, 5, 1, 3,
        4, 6, 2, 5
    ]
})

result = (
    employees
    .groupby(["department", "gender"])["salary"]
    .mean()
)

result = result.reset_index()
result

# %% [markdown]
# # Task 103
#
# Given:
# ```python
# employees = pd.DataFrame({
#     "employee_id": [101, 102, 103, 104, 105, 106, 107, 108],
#     "name": [
#         "Ivan", "Maria", "Peter", "Anna",
#         "Georgi", "Elena", "Dimitar", "Nina"
#     ],
#     "department": [
#         "IT", "HR", "IT", "Sales",
#         "HR", "IT", "Sales", "HR"
#     ],
#     "gender": [
#         "M", "F", "M", "F",
#         "M", "F", "M", "F"
#     ],
#     "salary": [
#         3000, 3500, 2800, 2500,
#         3200, 3600, 2700, 3100
#     ],
#     "years_experience": [
#         2, 5, 1, 3,
#         4, 6, 2, 5
#     ]
# })
# ```
#
# Create a MultiIndex using `department` and `gender`
#
# Then answer:
# - What is the average salary for each department/gender combination?
# - Which combination has the highest average salary?
# - How many employees are in each department/gender combination?

# %%
employees = pd.DataFrame({
    "employee_id": [101, 102, 103, 104, 105, 106, 107, 108],
    "name": [
        "Ivan", "Maria", "Peter", "Anna",
        "Georgi", "Elena", "Dimitar", "Nina"
    ],
    "department": [
        "IT", "HR", "IT", "Sales",
        "HR", "IT", "Sales", "HR"
    ],
    "gender": [
        "M", "F", "M", "F",
        "M", "F", "M", "F"
    ],
    "salary": [
        3000, 3500, 2800, 2500,
        3200, 3600, 2700, 3100
    ],
    "years_experience": [
        2, 5, 1, 3,
        4, 6, 2, 5
    ]
})

employees.set_index(["department", "gender"], inplace=True)

employees.groupby(["department", "gender"])["salary"].mean()
employees.groupby(["department", "gender"])["salary"].mean().idxmax()
employees.groupby(["department", "gender"])["salary"].count()

employees.loc[employees.groupby(["department", "gender"])["salary"].mean().idxmax()]

# %% [markdown]
# # Task 104
#
# Given:
#
# ```python
# employees = pd.DataFrame({
#
#     "employee_id": [
#         101, 102, 103, 104, 105,
#         106, 107, 108, 108
#     ],
#
#     "name": [
#         "Ivan", " Maria ", "Peter", "Anna",
#         "Georgi", "Elena", "Dimitar", "Nina", "Nina"
#     ],
#
#     "department": [
#         "IT", "it", "HR", " HR ",
#         "Sales", "sales", "IT", "Unknown", "Unknown"
#     ],
#
#     "salary": [
#         "3000", "3500", "unknown", "3200",
#         "2500", "2,900", "-500", "3600", "3600"
#     ],
#
#     "hire_date": [
#         "2022-01-15", "2021-06-20", "invalid",
#         "2020-03-10", "2019-11-05", "2023-02-01",
#         "2022-08-15", "not available", "not available"
#     ]
#
# })
# ```
#
# ## Task 104.1:
#
# * Show the first rows.
# * Check the size.
# * Check the columns and types.
# * Check missing values.
# * Check duplicate rows.
# * Check the unique values of `department`.
# * Check the unique values of `salary`.
# * Check the unique values of `hire_date`.
#
# ## Task 104.2:
#
# * Show which rows are duplicates.
# * Show only duplicate rows.
# * Remove duplicate rows.
# * Check how many rows are left.
# * Check for duplicate `employee_id` values.
#
# ## Task 104.3:
#
# * Remove whitespace around the values in `department`.
# * Make all department values the same case.
# * Standardize the department names (`it` → `IT`, `hr` → `HR`, `sales` → `Sales`).
# * Replace the `Unknown` values with `NaN`.
# * Check the result with `employees["department"].unique()`.
#
# ## Task 104.4:
#
# * Check the type of the `salary` column.
# * Find out which values cannot be directly converted to numbers.
# * Use `pd.to_numeric(..., errors="coerce")`.
# * For now, create a new column `salary_numeric`, instead of overwriting the original one.
# * Remove the comma from `2,900`.
# * Convert the cleaned salary values to numeric values.
# * Identify invalid salary values.
# * Replace `-500` with `NaN` because a negative salary is an invalid business value.
# * Keep `unknown` as `NaN` after numeric conversion.
# * Check the result with `employees[["salary", "salary_numeric"]]`.
#
# ## Task 104.5:
#
# * Check the type of the `hire_date` column.
# * Convert `hire_date` to datetime using `pd.to_datetime(..., errors="coerce")`.
# * For now, create a new column `hire_date_clean`, instead of overwriting the original one.
# * Convert invalid date values such as `invalid` and `not available` to `NaT`.
# * Count the invalid or missing dates.
# * Show the rows with invalid or missing dates.
#
# ## Task 104.6:
#
# * Replace the original `hire_date` column with the cleaned datetime column.
# * Remove the temporary `hire_date_clean` column.
# * Check the data type of `hire_date`.
# * Check the minimum and maximum hire dates.
# * Check for future hire dates.
#
# ## Task 104.7:
#
# * Check the salary values after cleaning.
# * Check for remaining negative salary values.
# * Check for missing salary values.
# * Calculate descriptive statistics for `salary_numeric`.
# * Check that all valid salary values are greater than `0`.
#
# ## Task 104.8:
#
# * Calculate the number of years each employee has been with the company.
# * Create a new column `years_with_company`.
# * Use `hire_date` to calculate the number of years.
# * Check the result.
# * Keep `NaN` for employees whose `hire_date` is missing.
#
# ## Task 104.9:
#
# Perform a final data quality audit:
#
# * Check the shape of the DataFrame.
# * Check the data types.
# * Check the number of missing values in each column.
# * Check for duplicate rows.
# * Check for duplicate `employee_id` values.
# * Check the unique values of `department`.
# * Check for invalid salary values.
# * Check for future hire dates.
# * Review the final DataFrame.
# * Identify which employees still have missing information.
# * Decide whether the remaining missing values represent invalid data or simply unavailable information.
#
# ## Task 104.10:
#
# Create the final clean DataFrame:
#
# * Keep all valid employee records.
# * Keep missing values where the original information is unavailable.
# * Use the cleaned numeric salary values for analysis.
# * Use the cleaned datetime values for `hire_date`.
# * Remove temporary cleaning columns that are no longer needed.
# * Check the final DataFrame and its data types.
# * Confirm that the DataFrame is ready for further analysis.

# %%
employees = pd.DataFrame({
    "employee_id": [
        101, 102, 103, 104, 105,
        106, 107, 108, 108
    ],
    "name": [
        "Ivan", " Maria ", "Peter", "Anna",
        "Georgi", "Elena", "Dimitar", "Nina", "Nina"
    ],
    "department": [
        "IT", "it", "HR", " HR ",
        "Sales", "sales", "IT", "Unknown", "Unknown"
    ],
    "salary": [
        "3000", "3500", "unknown", "3200",
        "2500", "2,900", "-500", "3600", "3600"
    ],
    "hire_date": [
        "2022-01-15", "2021-06-20", "invalid",
        "2020-03-10", "2019-11-05", "2023-02-01",
        "2022-08-15", "not available", "not available"
    ]
})

employees.head()
employees.shape
employees.dtypes
employees.isna().sum()
employees.duplicated().sum()
employees["department"].unique()
employees["salary"].unique()
employees["hire_date"].unique()

employees[employees.duplicated() == True]
employees = employees.drop_duplicates()
employees.shape[0]

employees["employee_id"].duplicated()
employees.loc[employees["employee_id"].duplicated()]

employees["department"] = employees["department"].str.strip()
employees["department"] = employees["department"].str.lower()
employees["department"] = employees["department"].replace(
    {
        "it": "IT",
        "hr": "HR",
        "sales": "Sales",
        "unknown": np.nan
    }
)
employees["department"].unique()
employees["department"].isna().sum()

employees["salary"].dtypes
employees["salary"] = employees["salary"].str.replace(",", "")
employees["salary_numeric"] = pd.to_numeric(employees["salary"], errors="coerce")
employees[["salary", "salary_numeric"]]
employees.loc[employees["salary_numeric"] < 0, "salary_numeric"] = np.nan

employees["hire_date"].dtype
employees["hire_date_clean"] = pd.to_datetime(employees["hire_date"], errors="coerce")
employees[["hire_date", "hire_date_clean"]]
employees["hire_date_clean"].isna().sum()
employees.loc[employees["hire_date_clean"].isna(), ["employee_id", "name", "hire_date"]]
employees["hire_date"] = employees["hire_date_clean"]
employees.drop(columns="hire_date_clean", inplace=True)

employees.loc[employees["salary_numeric"].isna(), ["employee_id", "name", "salary", "salary_numeric"]]
employees.loc[employees["salary_numeric"] < 0,    ["employee_id", "name", "salary_numeric"]]
employees.loc[employees["salary_numeric"].notna() & (employees["salary_numeric"] > 0),
              ["employee_id", "name", "salary_numeric"]]
employees["salary_numeric"].describe()

employees.loc[employees["hire_date"].isna(), ["employee_id", "name", "hire_date"]]
employees.loc[employees["hire_date"] > pd.Timestamp.today(), ["employee_id", "name", "hire_date"]]
employees["hire_date"].min()
employees["hire_date"].max()
employees["years_with_company"] = (pd.Timestamp.today() - employees["hire_date"]).dt.days / 365.25
employees[["name", "hire_date", "years_with_company"]]

employees.info()
employees.shape
employees.isna().sum()
employees.duplicated().sum()
employees["employee_id"].duplicated().sum()
employees["department"].unique()
employees["salary_numeric"].describe()
employees.loc[employees["salary_numeric"] <= 0, ["employee_id", "name", "salary_numeric"]]
employees.isna().sum(axis=1)

employees["salary"] = employees["salary_numeric"]
employees.drop(columns="salary_numeric", inplace=True)

employees
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   employee_id         8 non-null      int64
#  1   name                8 non-null      str
#  2   department          7 non-null      str
#  3   salary              8 non-null      str
#  4   hire_date           6 non-null      datetime64[us]
#  5   salary_numeric      6 non-null      float64
#  6   years_with_company  6 non-null      float64
# dtypes: datetime64[us](1), float64(2), int64(1), str(3)
# memory usage: 580.0 bytes
#    employee_id     name department  salary  hire_date  years_with_company
# 0          101     Ivan         IT  3000.0 2022-01-15            4.654346
# 1          102   Maria          IT  3500.0 2021-06-20            5.226557
# 2          103    Peter         HR     NaN        NaT                 NaN
# 3          104     Anna         HR  3200.0 2020-03-10            6.505133
# 4          105   Georgi      Sales  2500.0 2019-11-05            6.850103
# 5          106    Elena      Sales  2900.0 2023-02-01            3.608487
# 6          107  Dimitar         IT     NaN 2022-08-15            4.073922
# 7          108     Nina        NaN  3600.0        NaT                 NaN
